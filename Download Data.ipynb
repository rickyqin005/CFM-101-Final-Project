# %%
## Author: Alexander Domilescu

from IPython.display import display, Math, Latex

import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import random as r
from datetime import datetime
import requests
import math

startdate = '2023-01-01'
enddate = '2023-10-31'
ticker_file = 'Tickers_Example.csv' # INSERT NAME OF ASSIGNMENT .CSV FILE

# produces a list of dictionaries for a given csv file of stock tickers
# each dictionary contains three items:
# 1. a dictionary of all the stock's information
# 2. a dataframe of the daily close prices of the stock between the given start and end dates
# 3. a dataframe of the daily volume of the stock between the given start and end dates
def download_data(start_date, end_date, ticker_file):
    # create an empty list that will be filled with stock data and outputted
    stock_data = []
    # read the given ticker file into a list
    tickers = pd.read_csv('Tickers_Example.csv', header=None).values.flatten().tolist()
    
    # cycles through the list of given tickers to fill the empty stock_data list
    for i in tickers:
        temp_ticker = yf.Ticker(i)
        # download the stock data for the current stock
        temp_data = yf.download(i, start=startdate, end=enddate)
        temp_close = temp_data.Close
        temp_volume = temp_data.Volume
        # append a dictionary of the stock's information, daily close prices, and volume to the stock_data list
        stock_data.append({'info': temp_ticker.info,
                           'close': temp_close,
                           'volume': temp_volume})
    return stock_data

unfiltered_stock_data = download_data(startdate, enddate, raw_tickers)
unfiltered_stock_data

# HOW TO USE THE OUTPUT OF download_data:
# ---------------------------------------
# stock_data[3]['info']['beta'] - returns the beta for the fourth stock in the list
# stock_data[1]['volume'] - returns a dataframe of the volume of the second stock in the list
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['AGN']: Exception('%ticker%: No timezone found, symbol may be delisted')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...
