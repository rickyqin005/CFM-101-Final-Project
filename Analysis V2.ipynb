# %%
## Authors: Tong Liu

from IPython.display import display, Math, Latex

import pandas as pd
import numpy as np
import numpy_financial as npf
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime

# %%
startdate = '2023-01-01'
enddate = '2023-10-31'

ticker_file = 'Tickers_Example.csv' 
tickers = pd.read_csv(ticker_file, header=None).values.flatten().tolist() 

#currency conversion
CAD_transfer = yf.Ticker('CADUSD=x')
transferRate = CAD_transfer.history(start=startdate, end=enddate)
CAD_to_USD = transferRate[['Close']]
CAD_to_USD.index = CAD_to_USD.index.strftime('%Y-%m-%d')
    
def currency_exchange(base, currency):
    base.index = base.index.strftime('%Y-%m-%d')
    if currency == 'USD':
        exchange_rates = pd.DataFrame()
        exchange_rates['Close'] = base['Close']/CAD_to_USD['Close']
        exchange_rates = exchange_rates.dropna()
        return exchange_rates
    else:
        return base

msft = yf.Ticker('MSFT')
hist = msft.history(start=startdate, end=enddate)
currency_exchange(hist[['Close']], 'USD')
# Out:
#                  Close
# Date
# 2023-01-03  321.991489
# 2023-01-04  310.520276
# 2023-01-05  297.152436
# 2023-01-06  302.322177
# 2023-01-09  302.458393
# ...                ...
# 2023-10-24  451.529563
# 2023-10-25  467.186900
# 2023-10-26  451.666606
# 2023-10-27  454.676707
# 2023-10-30  466.679147
#
# [208 rows x 1 columns]

# %%
def is_valid_currency(ticker):
    stock_info = yf.Ticker(ticker).info
    currency = stock_info.get('currency', '').upper() # retrieving the stock currency
    return currency == 'USD' or currency == 'CAD' # returns T/F based on currency

# %%
def get_stock_data(ticker):
    # get stock info
    stock_info = yf.Ticker(ticker).info
    
    # check if the currency is valid
    if is_valid_currency(ticker):
        # download historical data
        data = yf.download(ticker, start=startdate, end=enddate)
        
        # returning daily volume
        monthly_volume = data['Volume'].resample('D').sum()
        
        #turning American stocks to CAD$
        stock_price = currency_exchange(data[['Close']], stock_info['currency'])
        
        # create a dictionary for the ticker
        result = {
            'ticker': ticker,
            'info': stock_info,
            'close': stock_price,
            'volume': pd.DataFrame(monthly_volume)
        }
        return result
    else:
        print(f"Skipping {ticker}: Invalid currency.")
        return None

# accumulates a list of dictionaries through get_stock_data    
def process_tickers(ticker_list):
    result_list = []
    for ticker in ticker_list:
        stock_data = get_stock_data(ticker)
        if stock_data is not None:
            result_list.append(stock_data)
    return result_list

result_list = process_tickers(tickers)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Skipping AGN: Invalid currency.
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Skipping CELG: Invalid currency.
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Skipping MON: Invalid currency.
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Skipping RTN: Invalid currency.
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
def filter_stocks(result_list, min_avg_volume=150000, min_trading_days=18):
    filtered_list = []

    for stock_data in result_list:
        ticker = stock_data['ticker']
        volume_data = stock_data['volume']

        # calculate average monthly volume
        monthly_avg_volume = {}
        for date, volume in volume_data.iterrows():
            month = date.strftime('%Y-%m')
            if month not in monthly_avg_volume:
                monthly_avg_volume[month] = {'total_volume': 0, 'days_counted': 0}
            if volume['Volume'] > 0 or monthly_avg_volume[month]['days_counted'] < min_trading_days:
                monthly_avg_volume[month]['total_volume'] += volume['Volume']
                monthly_avg_volume[month]['days_counted'] += 1

        # remove stocks with less than min_trading_days in any month or average volume less than min_avg_volume
        valid_months = [month for month, data in monthly_avg_volume.items() if data['days_counted'] >= min_trading_days]
        avg_monthly_volume = sum(monthly_avg_volume[month]['total_volume'] / data['days_counted'] for month, data in monthly_avg_volume.items() if data['days_counted'] > 0) / len(valid_months) if valid_months else 0

        if avg_monthly_volume >= min_avg_volume:
            filtered_list.append(stock_data)

    return filtered_list

filtered_list = filter_stocks(result_list)
filtered_list
# Out:
# [{'ticker': 'AAPL',
#   'info': {'address1': 'One Apple Park Way',
#    'city': 'Cupertino',
#    'state': 'CA',
#    'zip': '95014',
#    'country': 'United States',
#    'phone': '408 996 1010',
#    'website': 'https://www.apple.com',
#    'industry': 'Consumer Electronics',
#    'industryKey': 'consumer-electronics',
#    'industryDisp': 'Consumer Electronics',
#    'sector': 'Technology',
#    'sectorKey': 'technology',
#    'sectorDisp': 'Technology',
#    'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#    'fullTimeEmployees': 161000,
#    'companyOfficers': [{'maxAge': 1,
#      'name': 'Mr. Timothy D. Cook',
#      'age': 61,
#      'title': 'CEO & Director',
#      'yearBorn': 1961,
#      'fiscalYear': 2022,
#      'totalPay': 16425933,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Luca  Maestri',
#      'age': 59,
#      'title': 'CFO & Senior VP',
#      'yearBorn': 1963,
#      'fiscalYear': 2022,
#      'totalPay': 5019783,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Jeffrey E. Williams',
#      'age': 58,
#      'title': 'Chief Operating Officer',
#      'yearBorn': 1964,
#      'fiscalYear': 2022,
#      'totalPay': 5018337,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Katherine L. Adams',
#      'age': 58,
#      'title': 'Senior VP, General Counsel & Secretary',
#      'yearBorn': 1964,
#      'fiscalYear': 2022,
#      'totalPay': 5015208,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': "Ms. Deirdre  O'Brien",
#      'age': 55,
#      'title': 'Senior Vice President of Retail',
#      'yearBorn': 1967,
#      'fiscalYear': 2022,
#      'totalPay': 5019783,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Chris  Kondo',
#      'title': 'Senior Director of Corporate Accounting',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. James  Wilson',
#      'title': 'Chief Technology Officer',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Mary  Demby',
#      'title': 'Chief Information Officer',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Suhasini  Chandramouli',
#      'title': 'Director of Investor Relations',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Greg  Joswiak',
#      'title': 'Senior Vice President of Worldwide Marketing',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0}],
#    'auditRisk': 5,
#    'boardRisk': 1,
#    'compensationRisk': 5,
#    'shareHolderRightsRisk': 1,
#    'overallRisk': 1,
#    'governanceEpochDate': 1698796800,
#    'compensationAsOfEpochDate': 1672444800,
#    'maxAge': 86400,
#    'priceHint': 2,
#    'previousClose': 191.31,
#    'open': 190.87,
#    'dayLow': 189.25,
#    'dayHigh': 190.9,
#    'regularMarketPreviousClose': 191.31,
#    'regularMarketOpen': 190.87,
#    'regularMarketDayLow': 189.25,
#    'regularMarketDayHigh': 190.9,
#    'dividendRate': 0.96,
#    'dividendYield': 0.005,
#    'exDividendDate': 1699574400,
#    'payoutRatio': 0.1533,
#    'fiveYearAvgDividendYield': 0.84,
#    'beta': 1.305,
#    'trailingPE': 31.04085,
#    'forwardPE': 26.532124,
#    'volume': 24048344,
#    'regularMarketVolume': 24048344,
#    'averageVolume': 58491269,
#    'averageVolume10days': 50701620,
#    'averageDailyVolume10Day': 50701620,
#    'bid': 189.85,
#    'ask': 189.95,
#    'bidSize': 1300,
#    'askSize': 800,
#    'marketCap': 2954565517312,
#    'fiftyTwoWeekLow': 124.17,
#    'fiftyTwoWeekHigh': 198.23,
#    'priceToSalesTrailing12Months': 7.7085342,
#    'fiftyDayAverage': 177.7814,
#    'twoHundredDayAverage': 174.14445,
#    'trailingAnnualDividendRate': 0.94,
#    'trailingAnnualDividendYield': 0.004913491,
#    'currency': 'USD',
#    'enterpriseValue': 3016931409920,
#    'profitMargins': 0.25305998,
#    'floatShares': 15535177390,
#    'sharesOutstanding': 15552799744,
#    'sharesShort': 98190963,
#    'sharesShortPriorMonth': 94725628,
#    'sharesShortPreviousMonthDate': 1695945600,
#    'dateShortInterest': 1698710400,
#    'sharesPercentSharesOut': 0.0063,
#    'heldPercentInsiders': 0.00071999995,
#    'heldPercentInstitutions': 0.61317,
#    'shortRatio': 1.84,
#    'shortPercentOfFloat': 0.0063,
#    'impliedSharesOutstanding': 15552799744,
#    'bookValue': 3.997,
#    'priceToBook': 47.528145,
#    'lastFiscalYearEnd': 1696032000,
#    'nextFiscalYearEnd': 1727654400,
#    'mostRecentQuarter': 1696032000,
#    'earningsQuarterlyGrowth': 0.108,
#    'netIncomeToCommon': 96995000320,
#    'trailingEps': 6.12,
#    'forwardEps': 7.16,
#    'pegRatio': 4.74,
#    'lastSplitFactor': '4:1',
#    'lastSplitDate': 1598832000,
#    'enterpriseToRevenue': 7.871,
#    'enterpriseToEbitda': 23.978,
#    '52WeekChange': 0.2916751,
#    'SandP52WeekChange': 0.13176453,
#    'lastDividendValue': 0.24,
#    'lastDividendDate': 1699574400,
#    'exchange': 'NMS',
#    'quoteType': 'EQUITY',
#    'symbol': 'AAPL',
#    'underlyingSymbol': 'AAPL',
#    'shortName': 'Apple Inc.',
#    'longName': 'Apple Inc.',
#    'firstTradeDateEpochUtc': 345479400,
#    'timeZoneFullName': 'America/New_York',
#    'timeZoneShortName': 'EST',
#    'uuid': '8b10e4ae-9eeb-3684-921a-9ab27e4d87aa',
#    'messageBoardId': 'finmb_24937',
#    'gmtOffSetMilliseconds': -18000000,
#    'currentPrice': 189.97,
#    'targetHighPrice': 240.0,
#    'targetLowPrice': 159.0,
#    'targetMeanPrice': 198.01,
#    'targetMedianPrice': 200.0,
#    'recommendationMean': 2.1,
#    'recommendationKey': 'buy',
#    'numberOfAnalystOpinions': 39,
#    'totalCash': 61554999296,
#    'totalCashPerShare': 3.958,
#    'ebitda': 125820002304,
#    'totalDebt': 123930001408,
#    'quickRatio': 0.843,
#    'currentRatio': 0.988,
#    'totalRevenue': 383285002240,
#    'debtToEquity': 199.418,
#    'revenuePerShare': 24.344,
#    'returnOnAssets': 0.20256001,
#    'returnOnEquity': 1.7195,
#    'grossProfits': 170782000000,
#    'freeCashflow': 82179997696,
#    'operatingCashflow': 110543003648,
#    'earningsGrowth': 0.135,
#    'revenueGrowth': -0.007,
#    'grossMargins': 0.44131002,
#    'ebitdaMargins': 0.32827,
#    'operatingMargins': 0.30134,
#    'financialCurrency': 'USD',
#    'trailingPegRatio': 2.2608},
#   'close':                  Close
#   Date
#   2023-01-03  169.582422
#   2023-01-04  172.785920
#   2023-01-05  168.590715
#   2023-01-06  175.763423
#   2023-01-09  174.859126
#   ...                ...
#   2023-10-24  237.413353
#   2023-10-25  235.118790
#   2023-10-26  230.356609
#   2023-10-27  232.379106
#   2023-10-30  236.079824
#
#   [208 rows x 1 columns],
#   'volume':                Volume
#   Date
#   2023-01-03  112117500
#   2023-01-04   89113600
#   2023-01-05   80962700
#   2023-01-06   87754700
#   2023-01-07          0
#   ...               ...
#   2023-10-26   70625300
#   2023-10-27   58499100
#   2023-10-28          0
#   2023-10-29          0
#   2023-10-30   51131000
#
#   [301 rows x 1 columns]},
#  {'ticker': 'ABBV',
#   'info': {'address1': '1 North Waukegan Road',
#    'city': 'North Chicago',
#    'state': 'IL',
#    'zip': '60064-6400',
#    'country': 'United States',
#    'phone': '847 932 7900',
#    'website': 'https://www.abbvie.com',
#    'industry': 'Drug Manufacturers - General',
#    'industryKey': 'drug-manufacturers-general',
#    'industryDisp': 'Drug Manufacturers - General',
#    'sector': 'Healthcare',
#    'sectorKey': 'healthcare',
#    'sectorDisp': 'Healthcare',
#    'longBusinessSummary': "AbbVie Inc. discovers, develops, manufactures, and sells pharmaceuticals worldwide. The company offers Humira, a therapy administered as an injection for autoimmune, intestinal Behçet's diseases, and pyoderma gangrenosum; Skyrizi to treat moderate to severe plaque psoriasis, psoriatic disease, and Crohn's disease; Rinvoq, a JAK inhibitor to treat rheumatoid and psoriatic arthritis, ankylosing spondylitis, atopic dermatitis, axial spondyloarthropathy, and ulcerative colitis; Imbruvica for the treatment of adult patients with blood cancers; and Venclexta/Venclyxto to treat hematological malignancies. It also provides facial injectables, plastics and regenerative medicine, body contouring, and skincare products; Vraylar for depressive disorder; Duopa and Duodopa to treat advanced Parkinson's disease; and Ubrelvy for the acute treatment of migraine with or without aura in adults; Qulipta for episodic migraine. In addition, the company offers Lumigan/Ganfort and Alphagan/Combigan for the reduction of elevated intraocular pressure(IOP) in patients with open angle glaucoma (OAG) or ocular hypertension; Restasis, a calcineurin inhibitor immunosuppressant indicated to increase tear production; and eye care products. Further, it provides Mavyret/Maviret to treat chronic hepatitis C virus (HCV) genotype 1-6 infection and HCV genotype 1 infection; Creon, a pancreatic enzyme therapy; Lupron to treat advanced prostate cancer, endometriosis and central precocious puberty, and patients with anemia caused by uterine fibroids; Linzess/Constella to treat irritable bowel syndrome with constipation and chronic idiopathic constipation; and Synthroid for hypothyroidism. It has collaborations with Calico Life Sciences LLC; REGENXBIO Inc.; I-Mab Biopharma; Genmab A/S; Janssen Biotech, Inc.; Genentech, Inc.; and California Institute for Biomedical Research (Calibr). The company was incorporated in 2012 and is headquartered in North Chicago, Illinois.",
#    'fullTimeEmployees': 50000,
#    'companyOfficers': [{'maxAge': 1,
#      'name': 'Mr. Richard A. Gonzalez',
#      'age': 68,
#      'title': 'Chairman & CEO',
#      'yearBorn': 1954,
#      'fiscalYear': 2022,
#      'totalPay': 6948244,
#      'exercisedValue': 0,
#      'unexercisedValue': 43528872},
#     {'maxAge': 1,
#      'name': 'Mr. Robert A. Michael',
#      'age': 52,
#      'title': 'President & COO',
#      'yearBorn': 1970,
#      'fiscalYear': 2022,
#      'totalPay': 3998042,
#      'exercisedValue': 0,
#      'unexercisedValue': 13150419},
#     {'maxAge': 1,
#      'name': 'Mr. Scott T. Reents',
#      'age': 54,
#      'title': 'Executive VP & CFO',
#      'yearBorn': 1968,
#      'fiscalYear': 2022,
#      'totalPay': 2972736,
#      'exercisedValue': 0,
#      'unexercisedValue': 5172329},
#     {'maxAge': 1,
#      'name': 'Dr. Azita  Saleki-Gerhardt Ph.D.',
#      'age': 59,
#      'title': 'Executive VP & COO',
#      'yearBorn': 1963,
#      'fiscalYear': 2022,
#      'totalPay': 2576755,
#      'exercisedValue': 0,
#      'unexercisedValue': 28534760},
#     {'maxAge': 1,
#      'name': 'Mr. Jeffrey Ryan Stewart',
#      'age': 53,
#      'title': 'Executive VP & Chief Commercial Officer',
#      'yearBorn': 1969,
#      'fiscalYear': 2022,
#      'totalPay': 2983231,
#      'exercisedValue': 2777988,
#      'unexercisedValue': 10864175},
#     {'maxAge': 1,
#      'name': 'Dr. Thomas J. Hudson M.D.',
#      'age': 60,
#      'title': 'Senior VP of Research & Development and Chief Scientific Officer',
#      'yearBorn': 1962,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Elizabeth  Shea',
#      'title': 'Senior Vice President of Investor Relations',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Sanjay  Narayan',
#      'title': 'VP, Chief Ethics & Compliance Officer',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Tracie  Haas',
#      'title': 'Senior Vice President of Corporate Responsibility, Brand & Communications',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Timothy J. Richmond',
#      'age': 56,
#      'title': 'Executive VP & Chief Human Resources Officer',
#      'yearBorn': 1966,
#      'fiscalYear': 2022,
#      'totalPay': 1121841,
#      'exercisedValue': 0,
#      'unexercisedValue': 0}],
#    'auditRisk': 9,
#    'boardRisk': 7,
#    'compensationRisk': 7,
#    'shareHolderRightsRisk': 9,
#    'overallRisk': 9,
#    'governanceEpochDate': 1698796800,
#    'compensationAsOfEpochDate': 1672444800,
#    'maxAge': 86400,
#    'priceHint': 2,
#    'previousClose': 138.47,
#    'open': 140.0,
#    'dayLow': 138.46,
#    'dayHigh': 140.08,
#    'regularMarketPreviousClose': 138.47,
#    'regularMarketOpen': 140.0,
#    'regularMarketDayLow': 138.46,
#    'regularMarketDayHigh': 140.08,
#    'dividendRate': 6.2,
#    'dividendYield': 0.0448,
#    'exDividendDate': 1705017600,
#    'payoutRatio': 1.6027,
#    'fiveYearAvgDividendYield': 4.49,
#    'beta': 0.477,
#    'trailingPE': 37.887978,
#    'forwardPE': 12.414503,
#    'volume': 1564560,
#    'regularMarketVolume': 1564560,
#    'averageVolume': 4741049,
#    'averageVolume10days': 5719240,
#    'averageDailyVolume10Day': 5719240,
#    'bid': 138.5,
#    'ask': 138.72,
#    'bidSize': 800,
#    'askSize': 800,
#    'marketCap': 244827422720,
#    'fiftyTwoWeekLow': 130.96,
#    'fiftyTwoWeekHigh': 168.11,
#    'priceToSalesTrailing12Months': 4.4402666,
#    'fiftyDayAverage': 145.9026,
#    'twoHundredDayAverage': 147.3984,
#    'trailingAnnualDividendRate': 5.92,
#    'trailingAnnualDividendYield': 0.042752944,
#    'currency': 'USD',
#    'enterpriseValue': 292754063360,
#    'profitMargins': 0.118140005,
#    'floatShares': 1762730217,
#    'sharesOutstanding': 1765539968,
#    'sharesShort': 13234197,
#    'sharesShortPriorMonth': 12311421,
#    'sharesShortPreviousMonthDate': 1695945600,
#    'dateShortInterest': 1698710400,
#    'sharesPercentSharesOut': 0.0075,
#    'heldPercentInsiders': 0.00131,
#    'heldPercentInstitutions': 0.71415,
#    'shortRatio': 2.62,
#    'shortPercentOfFloat': 0.0075,
#    'impliedSharesOutstanding': 1765539968,
#    'bookValue': 6.85,
#    'priceToBook': 20.243795,
#    'lastFiscalYearEnd': 1672444800,
#    'nextFiscalYearEnd': 1703980800,
#    'mostRecentQuarter': 1696032000,
#    'earningsQuarterlyGrowth': -0.55,
#    'netIncomeToCommon': 6471000064,
#    'trailingEps': 3.66,
#    'forwardEps': 11.17,
#    'pegRatio': -2.93,
#    'enterpriseToRevenue': 5.309,
#    'enterpriseToEbitda': 10.458,
#    '52WeekChange': -0.1325022,
#    'SandP52WeekChange': 0.13176453,
#    'lastDividendValue': 1.48,
#    'lastDividendDate': 1697068800,
#    'exchange': 'NYQ',
#    'quoteType': 'EQUITY',
#    'symbol': 'ABBV',
#    'underlyingSymbol': 'ABBV',
#    'shortName': 'AbbVie Inc.',
#    'longName': 'AbbVie Inc.',
#    'firstTradeDateEpochUtc': 1357137000,
#    'timeZoneFullName': 'America/New_York',
#    'timeZoneShortName': 'EST',
#    'uuid': '73238d42-cdcc-3f92-8141-dd675addae10',
#    'messageBoardId': 'finmb_141885706',
#    'gmtOffSetMilliseconds': -18000000,
#    'currentPrice': 138.67,
#    'targetHighPrice': 205.0,
#    'targetLowPrice': 135.0,
#    'targetMeanPrice': 169.72,
#    'targetMedianPrice': 170.0,
#    'recommendationMean': 2.3,
#    'recommendationKey': 'buy',
#    'numberOfAnalystOpinions': 25,
#    'totalCash': 13290000384,
#    'totalCashPerShare': 7.527,
#    'ebitda': 27992999936,
#    'totalDebt': 61182001152,
#    'quickRatio': 0.71,
#    'currentRatio': 0.955,
#    'totalRevenue': 55138000896,
#    'debtToEquity': 504.427,
#    'revenuePerShare': 31.173,
#    'returnOnAssets': 0.086540006,
#    'returnOnEquity': 0.46321,
#    'grossProfits': 41527000000,
#    'freeCashflow': 24065499136,
#    'operatingCashflow': 25514000384,
#    'earningsGrowth': -0.548,
#    'revenueGrowth': -0.06,
#    'grossMargins': 0.69921,
#    'ebitdaMargins': 0.50769,
#    'operatingMargins': 0.17757,
#    'financialCurrency': 'USD',
#    'trailingPegRatio': None},
#   'close':                  Close
#   Date
#   2023-01-03  220.171061
#   2023-01-04  223.831335
#   2023-01-05  220.467906
#   2023-01-06  225.840146
#   2023-01-09  217.193456
#   ...                ...
#   2023-10-24  200.276445
#   2023-10-25  199.610478
#   2023-10-26  200.418114
#   2023-10-27  191.917889
#   2023-10-30  196.707778
#
#   [208 rows x 1 columns],
#   'volume':              Volume
#   Date
#   2023-01-03  4937500
#   2023-01-04  4440400
#   2023-01-05  3516000
#   2023-01-06  5099100
#   2023-01-07        0
#   ...             ...
#   2023-10-26  5569400
#   2023-10-27  9427200
#   2023-10-28        0
#   2023-10-29        0
#   2023-10-30  9258500
#
#   [301 rows x 1 columns]},
#  {'ticker': 'ABT',
#   'info': {'address1': '100 Abbott Park Road',
#    'address2': 'Abbott Park',
#    'city': 'North Chicago',
#    'state': 'IL',
#    'zip': '60064-6400',
#    'country': 'United States',
#    'phone': '224 667 6100',
#    'website': 'https://www.abbott.com',
#    'industry': 'Medical Devices',
#    'industryKey': 'medical-devices',
#    'industryDisp': 'Medical Devices',
#    'sector': 'Healthcare',
#    'sectorKey': 'healthcare',
#    'sectorDisp': 'Healthcare',
#    'longBusinessSummary': "Abbott Laboratories, together with its subsidiaries, discovers, develops, manufactures, and sells health care products worldwide. It operates in four segments: Established Pharmaceutical Products, Diagnostic Products, Nutritional Products, and Medical Devices. The Established Pharmaceutical Products segment provides generic pharmaceuticals for the treatment of pancreatic exocrine insufficiency, irritable bowel syndrome or biliary spasm, intrahepatic cholestasis or depressive symptoms, gynecological disorder, hormone replacement therapy, dyslipidemia, hypertension, hypothyroidism, Ménière's disease and vestibular vertigo, pain, fever, inflammation, and migraine, as well as provides anti-infective clarithromycin, influenza vaccine, and products to regulate physiological rhythm of the colon. The Diagnostic Products segment offers laboratory systems in the areas of immunoassay, clinical chemistry, hematology, and transfusion; molecular diagnostics systems that automate the extraction, purification, and preparation of DNA and RNA from patient samples, as well as detect and measure infectious agents; point of care systems; cartridges for testing blood; rapid diagnostics lateral flow testing products; molecular point-of-care testing for HIV, SARS-CoV-2, influenza A and B, RSV, and strep A; cardiometabolic test systems; drug and alcohol test, and remote patient monitoring and consumer self-test systems; and informatics and automation solutions for use in laboratories. The Nutritional Products segment provides pediatric and adult nutritional products. The Medical Devices segment offers rhythm management, electrophysiology, heart failure, vascular, and structural heart devices for the treatment of cardiovascular diseases; and diabetes care products, as well as neuromodulation devices for the management of chronic pain and movement disorders. Abbott Laboratories was founded in 1888 and is based in North Chicago, Illinois.",
#    'fullTimeEmployees': 115000,
#    'companyOfficers': [{'maxAge': 1,
#      'name': 'Mr. Robert B. Ford',
#      'age': 48,
#      'title': 'Chairman of the Board, President & CEO',
#      'yearBorn': 1974,
#      'fiscalYear': 2022,
#      'totalPay': 4052972,
#      'exercisedValue': 6643292,
#      'unexercisedValue': 65371608},
#     {'maxAge': 1,
#      'name': 'Mr. Hubert L. Allen',
#      'age': 56,
#      'title': 'Executive VP, General Counsel & Secretary',
#      'yearBorn': 1966,
#      'fiscalYear': 2022,
#      'totalPay': 2011146,
#      'exercisedValue': 0,
#      'unexercisedValue': 53734448},
#     {'maxAge': 1,
#      'name': 'Mr. Robert E. Funck Jr.',
#      'age': 61,
#      'title': 'Executive Vice President of Finance',
#      'yearBorn': 1961,
#      'fiscalYear': 2022,
#      'totalPay': 2163872,
#      'exercisedValue': 0,
#      'unexercisedValue': 18556432},
#     {'maxAge': 1,
#      'name': 'Mr. Daniel Gesua Sive Salvadori',
#      'age': 43,
#      'title': 'Executive VP and Group President of Established Pharmaceuticals & Nutritional Products',
#      'yearBorn': 1979,
#      'fiscalYear': 2022,
#      'totalPay': 1487312,
#      'exercisedValue': 0,
#      'unexercisedValue': 26139322},
#     {'maxAge': 1,
#      'name': 'Ms. Andrea F. Wainer',
#      'age': 52,
#      'title': 'Executive Vice President of Rapid & Molecular Diagnostics',
#      'yearBorn': 1970,
#      'fiscalYear': 2022,
#      'totalPay': 1750962,
#      'exercisedValue': 0,
#      'unexercisedValue': 12517049},
#     {'maxAge': 1,
#      'name': 'Mr. Philip P. Boudreau',
#      'age': 49,
#      'title': 'CFO & Senior VP of Finance',
#      'yearBorn': 1973,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Erica L. Battaglia',
#      'title': 'VP and Chief Ethics & Compliance Officer',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Melissa  Brotz',
#      'title': 'Vice President of Public Affairs & Corporate Marketing',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Mary K. Moreland',
#      'age': 56,
#      'title': 'Executive Vice President of Human Resources',
#      'yearBorn': 1966,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Jared L. Watkin',
#      'age': 54,
#      'title': 'Senior Vice President of Diabetes Care',
#      'yearBorn': 1968,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0}],
#    'auditRisk': 8,
#    'boardRisk': 9,
#    'compensationRisk': 9,
#    'shareHolderRightsRisk': 2,
#    'overallRisk': 8,
#    'governanceEpochDate': 1698796800,
#    'compensationAsOfEpochDate': 1672444800,
#    'maxAge': 86400,
#    'priceHint': 2,
#    'previousClose': 102.7,
#    'open': 102.68,
#    'dayLow': 102.19,
#    'dayHigh': 103.18,
#    'regularMarketPreviousClose': 102.7,
#    'regularMarketOpen': 102.68,
#    'regularMarketDayLow': 102.19,
#    'regularMarketDayHigh': 103.18,
#    'dividendRate': 2.04,
#    'dividendYield': 0.0199,
#    'exDividendDate': 1697068800,
#    'payoutRatio': 0.6803,
#    'fiveYearAvgDividendYield': 1.56,
#    'beta': 0.68,
#    'trailingPE': 34.989796,
#    'forwardPE': 22.266235,
#    'volume': 2097557,
#    'regularMarketVolume': 2097557,
#    'averageVolume': 5683311,
#    'averageVolume10days': 6240300,
#    'averageDailyVolume10Day': 6240300,
#    'bid': 102.41,
#    'ask': 102.99,
#    'bidSize': 1300,
#    'askSize': 800,
#    'marketCap': 178588499968,
#    'fiftyTwoWeekLow': 89.67,
#    'fiftyTwoWeekHigh': 115.83,
#    'priceToSalesTrailing12Months': 4.4692936,
#    'fiftyDayAverage': 96.4378,
#    'twoHundredDayAverage': 103.0557,
#    'trailingAnnualDividendRate': 2.04,
#    'trailingAnnualDividendYield': 0.01986368,
#    'currency': 'USD',
#    'enterpriseValue': 187453341696,
#    'profitMargins': 0.12918,
#    'floatShares': 1726058839,
#    'sharesOutstanding': 1736060032,
#    'sharesShort': 9882343,
#    'sharesShortPriorMonth': 10180964,
#    'sharesShortPreviousMonthDate': 1695945600,
#    'dateShortInterest': 1698710400,
#    'sharesPercentSharesOut': 0.0057,
#    'heldPercentInsiders': 0.0055,
#    'heldPercentInstitutions': 0.76387,
#    'shortRatio': 1.41,
#    'shortPercentOfFloat': 0.0057,
#    'impliedSharesOutstanding': 1736060032,
#    'bookValue': 21.59,
#    'priceToBook': 4.764706,
#    'lastFiscalYearEnd': 1672444800,
#    'nextFiscalYearEnd': 1703980800,
#    'mostRecentQuarter': 1696032000,
#    'earningsQuarterlyGrowth': 0.001,
#    'netIncomeToCommon': 5142000128,
#    'trailingEps': 2.94,
#    'forwardEps': 4.62,
#    'pegRatio': -11.56,
#    'lastSplitFactor': '10000:4798',
#    'lastSplitDate': 1357084800,
#    'enterpriseToRevenue': 4.691,
#    'enterpriseToEbitda': 18.99,
#    '52WeekChange': -0.039828002,
#    'SandP52WeekChange': 0.13176453,
#    'lastDividendValue': 0.51,
#    'lastDividendDate': 1697068800,
#    'exchange': 'NYQ',
#    'quoteType': 'EQUITY',
#    'symbol': 'ABT',
#    'underlyingSymbol': 'ABT',
#    'shortName': 'Abbott Laboratories',
#    'longName': 'Abbott Laboratories',
#    'firstTradeDateEpochUtc': 322151400,
#    'timeZoneFullName': 'America/New_York',
#    'timeZoneShortName': 'EST',
#    'uuid': '5f9c82b0-139d-3f8f-b30c-efd7ee9ccdcf',
#    'messageBoardId': 'finmb_247483',
#    'gmtOffSetMilliseconds': -18000000,
#    'currentPrice': 102.87,
#    'targetHighPrice': 133.0,
#    'targetLowPrice': 100.0,
#    'targetMeanPrice': 116.1,
#    'targetMedianPrice': 115.5,
#    'recommendationMean': 2.0,
#    'recommendationKey': 'buy',
#    'numberOfAnalystOpinions': 20,
#    'totalCash': 7047000064,
#    'totalCashPerShare': 4.059,
#    'ebitda': 9870999552,
#    'totalDebt': 15699000320,
#    'quickRatio': 1.039,
#    'currentRatio': 1.738,
#    'totalRevenue': 39958999040,
#    'debtToEquity': 41.649,
#    'revenuePerShare': 22.951,
#    'returnOnAssets': 0.05723,
#    'returnOnEquity': 0.14031,
#    'grossProfits': 24579000000,
#    'freeCashflow': 4627250176,
#    'operatingCashflow': 6549000192,
#    'earningsGrowth': 0.012,
#    'revenueGrowth': -0.026,
#    'grossMargins': 0.55172,
#    'ebitdaMargins': 0.24702999,
#    'operatingMargins': 0.17441,
#    'financialCurrency': 'USD',
#    'trailingPegRatio': 24.6194},
#   'close':                  Close
#   Date
#   2023-01-03  148.579533
#   2023-01-04  152.069657
#   2023-01-05  149.414911
#   2023-01-06  152.318364
#   2023-01-09  150.675775
#   ...                ...
#   2023-10-24  129.780668
#   2023-10-25  128.580154
#   2023-10-26  129.719665
#   2023-10-27  128.262986
#   2023-10-30  128.929617
#
#   [208 rows x 1 columns],
#   'volume':              Volume
#   Date
#   2023-01-03  4171900
#   2023-01-04  4395500
#   2023-01-05  4896900
#   2023-01-06  3800400
#   2023-01-07        0
#   ...             ...
#   2023-10-26  6838100
#   2023-10-27  5934100
#   2023-10-28        0
#   2023-10-29        0
#   2023-10-30  7168900
#
#   [301 rows x 1 columns]},
#  {'ticker': 'ACN',
#   'info': {'address1': '1 Grand Canal Square',
#    'address2': 'Grand Canal Harbour',
#    'city': 'Dublin',
#    'zip': 'D02 P820',
#    'country': 'Ireland',
#    'phone': '353 1 646 2000',
#    'fax': '353 1 646 2020',
#    'website': 'https://www.accenture.com',
#    'industry': 'Information Technology Services',
#    'industryKey': 'information-technology-services',
#    'industryDisp': 'Information Technology Services',
#    'sector': 'Technology',
#    'sectorKey': 'technology',
#    'sectorDisp': 'Technology',
#    'longBusinessSummary': 'Accenture plc, a professional services company, provides strategy and consulting, industry X, song, and technology and operation services worldwide. The company offers application services, including agile transformation, DevOps, application modernization, enterprise architecture, software and quality engineering, data management; intelligent automation comprising robotic process automation, natural language processing, and virtual agents; and application management services, as well as software engineering services; strategy and consulting services; data and analytics strategy, data discovery and augmentation, data management and beyond, data democratization, and industrialized solutions comprising turnkey analytics and artificial intelligence (AI) solutions; metaverse; and sustainability services. It also provides change management, HR transformation and delivery, organization strategy and design, talent strategy and development, and leadership and culture services; digital commerce; infrastructure services, including cloud infrastructure managed, cloud and data center, network, digital workplace, database platforms, service management, and cloud and infrastructure security services; data-enabled operating models; technology consulting and AI services; and technology consulting services. In addition, the company offers engineering and R&D digitization, smart connected products, product as-a-service enablement, capital projects, intelligent asset management, digital industrial workforce, and autonomous robotic systems; business process outsourcing; and services related to technology innovation. Further, it provides cloud, ecosystem, marketing, security, supply chain management, zero-based transformation, customer experience, finance consulting, mergers and acquisitions, and sustainability services. The company has a collaboration with Salesforce, Inc. to develop Salesforce Life Sciences Cloud. The company was founded in 1951 and is based in Dublin, Ireland.',
#    'fullTimeEmployees': 733000,
#    'companyOfficers': [{'maxAge': 1,
#      'name': 'Ms. Julie T. Spellman Sweet',
#      'age': 55,
#      'title': 'CEO & Chairman',
#      'yearBorn': 1967,
#      'fiscalYear': 2022,
#      'totalPay': 8210595,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Kathleen R. McClure',
#      'age': 56,
#      'title': 'Chief Financial Officer',
#      'yearBorn': 1966,
#      'fiscalYear': 2022,
#      'totalPay': 3139280,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Gianfranco  Casati',
#      'age': 63,
#      'title': 'Executive Chairman of Growth Markets',
#      'yearBorn': 1959,
#      'fiscalYear': 2022,
#      'totalPay': 3601521,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Jean-Marc  Ollagnier',
#      'age': 60,
#      'title': 'Chief Executive Officer of EMEA',
#      'yearBorn': 1962,
#      'fiscalYear': 2022,
#      'totalPay': 3544965,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. John  Walsh',
#      'age': 58,
#      'title': 'Chief Operating Officer',
#      'yearBorn': 1964,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Melissa A. Burgum',
#      'age': 49,
#      'title': 'Chief Accounting Officer & Corporate Controller',
#      'yearBorn': 1973,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Paul R. Daugherty',
#      'age': 58,
#      'title': 'Chief Technology & Innovation Officer',
#      'yearBorn': 1964,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Rajendra  Prasad',
#      'title': 'Chief Information & Asset Engineering Officer',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Angie  Park',
#      'title': 'Managing Director & Head of Investor Relations',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Joel  Unruch',
#      'age': 44,
#      'title': 'General Counsel & Corporate Secretary',
#      'yearBorn': 1978,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0}],
#    'auditRisk': 1,
#    'boardRisk': 3,
#    'compensationRisk': 4,
#    'shareHolderRightsRisk': 4,
#    'overallRisk': 1,
#    'governanceEpochDate': 1698796800,
#    'compensationAsOfEpochDate': 1672444800,
#    'maxAge': 86400,
#    'priceHint': 2,
#    'previousClose': 333.13,
#    'open': 333.15,
#    'dayLow': 332.09,
#    'dayHigh': 334.9018,
#    'regularMarketPreviousClose': 333.13,
#    'regularMarketOpen': 333.15,
#    'regularMarketDayLow': 332.09,
#    'regularMarketDayHigh': 334.9018,
#    'dividendRate': 5.16,
#    'dividendYield': 0.0155,
#    'exDividendDate': 1696982400,
#    'payoutRatio': 0.41599998,
#    'fiveYearAvgDividendYield': 1.38,
#    'beta': 1.219,
#    'trailingPE': 31.04461,
#    'forwardPE': 25.07808,
#    'volume': 687364,
#    'regularMarketVolume': 687364,
#    'averageVolume': 1912122,
#    'averageVolume10days': 1677380,
#    'averageDailyVolume10Day': 1677380,
#    'bid': 333.46,
#    'ask': 333.65,
#    'bidSize': 900,
#    'askSize': 1100,
#    'marketCap': 209817206784,
#    'fiftyTwoWeekLow': 242.8,
#    'fiftyTwoWeekHigh': 335.53,
#    'priceToSalesTrailing12Months': 3.2726798,
#    'fiftyDayAverage': 310.6414,
#    'twoHundredDayAverage': 297.9402,
#    'trailingAnnualDividendRate': 4.65,
#    'trailingAnnualDividendYield': 0.013958515,
#    'currency': 'USD',
#    'enterpriseValue': 204512739328,
#    'profitMargins': 0.10718001,
#    'floatShares': 626720908,
#    'sharesOutstanding': 627612032,
#    'sharesShort': 7656034,
#    'sharesShortPriorMonth': 6289737,
#    'sharesShortPreviousMonthDate': 1695945600,
#    'dateShortInterest': 1698710400,
#    'sharesPercentSharesOut': 0.012200001,
#    'heldPercentInsiders': 0.00135,
#    'heldPercentInstitutions': 0.74193,
#    'shortRatio': 4.08,
#    'shortPercentOfFloat': 0.012200001,
#    'impliedSharesOutstanding': 628120000,
#    'bookValue': 40.895,
#    'priceToBook': 8.168236,
#    'lastFiscalYearEnd': 1693440000,
#    'nextFiscalYearEnd': 1725062400,
#    'mostRecentQuarter': 1693440000,
#    'earningsQuarterlyGrowth': -0.175,
#    'netIncomeToCommon': 6871557120,
#    'trailingEps': 10.76,
#    'forwardEps': 13.32,
#    'pegRatio': 3.08,
#    'enterpriseToRevenue': 3.19,
#    'enterpriseToEbitda': 18.259,
#    '52WeekChange': 0.12392032,
#    'SandP52WeekChange': 0.13176453,
#    'lastDividendValue': 1.29,
#    'lastDividendDate': 1696982400,
#    'exchange': 'NYQ',
#    'quoteType': 'EQUITY',
#    'symbol': 'ACN',
#    'underlyingSymbol': 'ACN',
#    'shortName': 'Accenture plc',
#    'longName': 'Accenture plc',
#    'firstTradeDateEpochUtc': 995549400,
#    'timeZoneFullName': 'America/New_York',
#    'timeZoneShortName': 'EST',
#    'uuid': '64bf532c-0542-3794-9f22-7d6062a2458b',
#    'messageBoardId': 'finmb_972190',
#    'gmtOffSetMilliseconds': -18000000,
#    'currentPrice': 334.04,
#    'targetHighPrice': 410.0,
#    'targetLowPrice': 280.0,
#    'targetMeanPrice': 339.33,
#    'targetMedianPrice': 341.0,
#    'recommendationMean': 2.1,
#    'recommendationKey': 'buy',
#    'numberOfAnalystOpinions': 21,
#    'totalCash': 9049607168,
#    'totalCashPerShare': 14.419,
#    'ebitda': 11200529408,
#    'totalDebt': 3149033984,
#    'quickRatio': 1.181,
#    'currentRatio': 1.298,
#    'totalRevenue': 64111742976,
#    'debtToEquity': 11.902,
#    'revenuePerShare': 101.667,
#    'returnOnAssets': 0.1285,
#    'returnOnEquity': 0.28465998,
#    'grossProfits': 20731607000,
#    'freeCashflow': 8889172992,
#    'operatingCashflow': 9524268032,
#    'earningsGrowth': -0.173,
#    'revenueGrowth': 0.036,
#    'grossMargins': 0.32337,
#    'ebitdaMargins': 0.17469999,
#    'operatingMargins': 0.16504999,
#    'financialCurrency': 'USD',
#    'trailingPegRatio': None},
#   'close':                  Close
#   Date
#   2023-01-03  366.445567
#   2023-01-04  368.298186
#   2023-01-05  354.631172
#   2023-01-06  365.046069
#   2023-01-09  367.788613
#   ...                ...
#   2023-10-24  405.302802
#   2023-10-25  402.189148
#   2023-10-26  403.099924
#   2023-10-27  400.661261
#   2023-10-30  405.781727
#
#   [208 rows x 1 columns],
#   'volume':              Volume
#   Date
#   2023-01-03  2250100
#   2023-01-04  2052400
#   2023-01-05  2477100
#   2023-01-06  1587000
#   2023-01-07        0
#   ...             ...
#   2023-10-26  2692500
#   2023-10-27  1480300
#   2023-10-28        0
#   2023-10-29        0
#   2023-10-30  1843500
#
#   [301 rows x 1 columns]},
#  {'ticker': 'AIG',
#   'info': {'address1': '1271 Avenue of the Americas',
#    'city': 'New York',
#    'state': 'NY',
#    'zip': '10020',
#    'country': 'United States',
#    'phone': '212 770 7000',
#    'website': 'https://www.aig.com',
#    'industry': 'Insurance - Diversified',
#    'industryKey': 'insurance-diversified',
#    'industryDisp': 'Insurance - Diversified',
#    'sector': 'Financial Services',
#    'sectorKey': 'financial-services',
#    'sectorDisp': 'Financial Services',
#    'longBusinessSummary': "American International Group, Inc. offers insurance products for commercial, institutional, and individual customers in North America and internationally. It operates through General Insurance, and Life and Retirement segments. The General Insurance segment provides commercial and industrial property insurance, including business interruption and package insurance that cover exposure to made and natural disasters; general liability, environmental, commercial automobile liability, workers' compensation, excess casualty, and crisis management insurance products; and professional liability insurance. This segment also offers marine, energy-related property insurance, aviation, political risk, trade credit, trade finance, and portfolio solutions, as well as operates reinsurance business; voluntary and sponsor-paid personal accident, and supplemental health products; and personal auto and personal property insurance. The Life and Retirement segment offers individual retirement products, including variable, fixed index, and fixed annuities, as well as retail mutual funds; group retirement products comprising record-keeping, plan administrative and compliance services, financial planning, and advisory solutions; life insurance, including term and universal life insurance; and institutional markets products, which includes wrap products, structured settlement, pension risk transfer annuities, corporate and bank-owned life insurance, high net worth, and guaranteed investment contract products. The company distributes its products through a network of brokers, agents, advisors, banks, and other distributors. American International Group, Inc. was founded in 1919 and is headquartered in New York, New York.",
#    'fullTimeEmployees': 26200,
#    'companyOfficers': [{'maxAge': 1,
#      'name': 'Mr. Peter Salvatore Zaffino',
#      'age': 55,
#      'title': 'Chairman, CEO & President',
#      'yearBorn': 1967,
#      'fiscalYear': 2022,
#      'totalPay': 9666320,
#      'exercisedValue': 0,
#      'unexercisedValue': 5864164},
#     {'maxAge': 1,
#      'name': 'Mr. David Hughes McElroy',
#      'age': 63,
#      'title': 'Executive VP & CEO of General Insurance',
#      'yearBorn': 1959,
#      'fiscalYear': 2022,
#      'totalPay': 5193619,
#      'exercisedValue': 0,
#      'unexercisedValue': 1944637},
#     {'maxAge': 1,
#      'name': 'Mr. Kevin Timothy Hogan',
#      'age': 60,
#      'title': 'President & CEO of Corebridge Financial, Inc.',
#      'yearBorn': 1962,
#      'fiscalYear': 2022,
#      'totalPay': 3740420,
#      'exercisedValue': 0,
#      'unexercisedValue': 3244787},
#     {'maxAge': 1,
#      'name': 'Ms. Sabra Rose Purtill C.F.A.',
#      'age': 59,
#      'title': 'Executive VP & CFO',
#      'yearBorn': 1963,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Claude E. Wade',
#      'age': 54,
#      'title': 'Executive VP, Head of Global Business Operations & IT and Chief Digital Officer',
#      'yearBorn': 1968,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Elaine Ann Rocha',
#      'age': 49,
#      'title': 'Global Chief Investment Officer',
#      'yearBorn': 1973,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Kathleen  Carbone',
#      'age': 50,
#      'title': 'VP & Chief Accounting Officer',
#      'yearBorn': 1972,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. John P. Repko',
#      'age': 59,
#      'title': 'Executive VP & Chief Information Officer',
#      'yearBorn': 1963,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Quentin John McMillan',
#      'title': 'VP, MD & Head of Investor Relations',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Karen  Nelson',
#      'title': 'Chief Compliance Officer',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0}],
#    'auditRisk': 3,
#    'boardRisk': 1,
#    'compensationRisk': 1,
#    'shareHolderRightsRisk': 5,
#    'overallRisk': 1,
#    'governanceEpochDate': 1698796800,
#    'compensationAsOfEpochDate': 1672444800,
#    'maxAge': 86400,
#    'priceHint': 2,
#    'previousClose': 64.97,
#    'open': 65.1,
#    'dayLow': 65.02,
#    'dayHigh': 65.72,
#    'regularMarketPreviousClose': 64.97,
#    'regularMarketOpen': 65.1,
#    'regularMarketDayLow': 65.02,
#    'regularMarketDayHigh': 65.72,
#    'dividendRate': 1.44,
#    'dividendYield': 0.0222,
#    'exDividendDate': 1702425600,
#    'payoutRatio': 0.2361,
#    'fiveYearAvgDividendYield': 2.77,
#    'beta': 1.049,
#    'trailingPE': 11.32118,
#    'forwardPE': 8.602902,
#    'volume': 1424101,
#    'regularMarketVolume': 1424101,
#    'averageVolume': 3107095,
#    'averageVolume10days': 3099460,
#    'averageDailyVolume10Day': 3099460,
#    'bid': 65.21,
#    'ask': 65.95,
#    'bidSize': 900,
#    'askSize': 1200,
#    'marketCap': 45780029440,
#    'fiftyTwoWeekLow': 45.66,
#    'fiftyTwoWeekHigh': 65.72,
#    'priceToSalesTrailing12Months': 0.9128438,
#    'fiftyDayAverage': 61.9072,
#    'twoHundredDayAverage': 57.50955,
#    'trailingAnnualDividendRate': 1.36,
#    'trailingAnnualDividendYield': 0.020932738,
#    'currency': 'USD',
#    'enterpriseValue': 58511052800,
#    'profitMargins': 0.082770005,
#    'floatShares': 700601160,
#    'sharesOutstanding': 702040000,
#    'sharesShort': 5926896,
#    'sharesShortPriorMonth': 6614539,
#    'sharesShortPreviousMonthDate': 1695945600,
#    'dateShortInterest': 1698710400,
#    'sharesPercentSharesOut': 0.0084,
#    'heldPercentInsiders': 0.00319,
#    'heldPercentInstitutions': 0.91947,
#    'shortRatio': 1.96,
#    'shortPercentOfFloat': 0.0095,
#    'impliedSharesOutstanding': 702040000,
#    'bookValue': 56.061,
#    'priceToBook': 1.1631972,
#    'lastFiscalYearEnd': 1672444800,
#    'nextFiscalYearEnd': 1703980800,
#    'mostRecentQuarter': 1696032000,
#    'earningsQuarterlyGrowth': -0.262,
#    'netIncomeToCommon': 4121999872,
#    'trailingEps': 5.76,
#    'forwardEps': 7.58,
#    'pegRatio': 0.61,
#    'lastSplitFactor': '1:20',
#    'lastSplitDate': 1246406400,
#    'enterpriseToRevenue': 1.167,
#    'enterpriseToEbitda': 4.951,
#    '52WeekChange': 0.06368697,
#    'SandP52WeekChange': 0.13176453,
#    'lastDividendValue': 0.36,
#    'lastDividendDate': 1694649600,
#    'exchange': 'NYQ',
#    'quoteType': 'EQUITY',
#    'symbol': 'AIG',
#    'underlyingSymbol': 'AIG',
#    'shortName': 'American International Group, I',
#    'longName': 'American International Group, Inc.',
#    'firstTradeDateEpochUtc': 94833000,
#    'timeZoneFullName': 'America/New_York',
#    'timeZoneShortName': 'EST',
#    'uuid': '00364109-56c8-328a-a91c-6092045edb5f',
#    'messageBoardId': 'finmb_250388',
#    'gmtOffSetMilliseconds': -18000000,
#    'currentPrice': 65.21,
#    'targetHighPrice': 83.0,
#    'targetLowPrice': 67.0,
#    'targetMeanPrice': 73.0,
#    'targetMedianPrice': 72.0,
#    'recommendationMean': 2.1,
#    'recommendationKey': 'buy',
#    'numberOfAnalystOpinions': 15,
#    'totalCash': 15038000128,
#    'totalCashPerShare': 21.42,
#    'ebitda': 11816999936,
#    'totalDebt': 24054999040,
#    'quickRatio': 0.2,
#    'currentRatio': 0.845,
#    'totalRevenue': 50150998016,
#    'debtToEquity': 55.666,
#    'revenuePerShare': 68.663,
#    'returnOnAssets': 0.00843,
#    'returnOnEquity': 0.11637,
#    'grossProfits': 24968000000,
#    'freeCashflow': 1659250048,
#    'operatingCashflow': 4861000192,
#    'earningsGrowth': -0.208,
#    'revenueGrowth': -0.09,
#    'grossMargins': 0.31086,
#    'ebitdaMargins': 0.23562999,
#    'operatingMargins': 0.306,
#    'financialCurrency': 'USD',
#    'trailingPegRatio': None},
#   'close':                 Close
#   Date
#   2023-01-03  85.326792
#   2023-01-04  87.322799
#   2023-01-05  85.643867
#   2023-01-06  87.529162
#   2023-01-09  85.810624
#   ...               ...
#   2023-10-24  81.953050
#   2023-10-25  83.768794
#   2023-10-26  83.990649
#   2023-10-27  82.234739
#   2023-10-30  84.566738
#
#   [208 rows x 1 columns],
#   'volume':              Volume
#   Date
#   2023-01-03  3363500
#   2023-01-04  3763600
#   2023-01-05  3902300
#   2023-01-06  2893400
#   2023-01-07        0
#   ...             ...
#   2023-10-26  2788200
#   2023-10-27  3097600
#   2023-10-28        0
#   2023-10-29        0
#   2023-10-30  3075900
#
#   [301 rows x 1 columns]},
#  {'ticker': 'AMZN',
#   'info': {'address1': '410 Terry Avenue North',
#    'city': 'Seattle',
#    'state': 'WA',
#    'zip': '98109-5210',
#    'country': 'United States',
#    'phone': '206 266 1000',
#    'website': 'https://www.aboutamazon.com',
#    'industry': 'Internet Retail',
#    'industryKey': 'internet-retail',
#    'industryDisp': 'Internet Retail',
#    'sector': 'Consumer Cyclical',
#    'sectorKey': 'consumer-cyclical',
#    'sectorDisp': 'Consumer Cyclical',
#    'longBusinessSummary': "Amazon.com, Inc. engages in the retail sale of consumer products and subscriptions through online and physical stores in North America and internationally. It operates through three segments: North America, International, and Amazon Web Services (AWS). The company's products offered through its stores include merchandise and content purchased for resale; and products offered by third-party sellers. It also manufactures and sells electronic devices, including Kindle, Fire tablets, Fire TVs, Rings, Blink, eero, and Echo; and develops and produces media content. In addition, the company offers programs that enable sellers to sell their products in its stores; and programs that allow authors, musicians, filmmakers, Twitch streamers, skill and app developers, and others to publish and sell content. Further, it provides compute, storage, database, analytics, machine learning, and other services, as well as fulfillment, advertising, and digital content subscriptions. Additionally, the company offers Amazon Prime, a membership program. It serves consumers, sellers, developers, enterprises, content creators, and advertisers. The company was incorporated in 1994 and is headquartered in Seattle, Washington.",
#    'fullTimeEmployees': 1500000,
#    'companyOfficers': [{'maxAge': 1,
#      'name': 'Mr. Jeffrey P. Bezos',
#      'age': 58,
#      'title': 'Founder & Executive Chairman',
#      'yearBorn': 1964,
#      'fiscalYear': 2022,
#      'totalPay': 1681840,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Andrew R. Jassy',
#      'age': 54,
#      'title': 'President, CEO & Director',
#      'yearBorn': 1968,
#      'fiscalYear': 2022,
#      'totalPay': 1298723,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Brian T. Olsavsky',
#      'age': 58,
#      'title': 'Senior VP & CFO',
#      'yearBorn': 1964,
#      'fiscalYear': 2022,
#      'totalPay': 319850,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. David A. Zapolsky',
#      'age': 58,
#      'title': 'Senior VP of Global Public Policy & General Counsel',
#      'yearBorn': 1964,
#      'fiscalYear': 2022,
#      'totalPay': 319850,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Douglas J. Herrington',
#      'age': 55,
#      'title': 'Chief Executive Officer of Worldwide Amazon Stores',
#      'yearBorn': 1967,
#      'fiscalYear': 2022,
#      'totalPay': 335438,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Adam N. Selipsky',
#      'age': 55,
#      'title': 'Chief Executive Officer of Amazon Web Services, Inc.',
#      'yearBorn': 1967,
#      'fiscalYear': 2022,
#      'totalPay': 360613,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
# ...
#    'fullTimeEmployees': 500000,
#    'companyOfficers': [{'maxAge': 1,
#      'name': 'Ms. Carol B. Tome',
#      'age': 65,
#      'title': 'CEO & Director',
#      'yearBorn': 1957,
#      'fiscalYear': 2022,
#      'totalPay': 2689686,
#      'exercisedValue': 0,
#      'unexercisedValue': 3097876},
#     {'maxAge': 1,
#      'name': 'Mr. Brian O. Newman',
#      'age': 53,
#      'title': 'Executive VP & CFO',
#      'yearBorn': 1969,
#      'fiscalYear': 2022,
#      'totalPay': 1242943,
#      'exercisedValue': 0,
#      'unexercisedValue': 855975},
#     {'maxAge': 1,
#      'name': 'Mr. Bala  Subramanian',
#      'age': 51,
#      'title': 'EVP and Chief Digital & Technology Officer',
#      'yearBorn': 1971,
#      'fiscalYear': 2022,
#      'totalPay': 581785,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Kathleen M. Gutmann',
#      'age': 53,
#      'title': 'Executive VP and President of International, Healthcare & Supply Chain Solutions',
#      'yearBorn': 1969,
#      'fiscalYear': 2022,
#      'totalPay': 1166151,
#      'exercisedValue': 2807919,
#      'unexercisedValue': 1345457},
#     {'maxAge': 1,
#      'name': 'Mr. Nando  Cesarone',
#      'age': 50,
#      'title': 'Executive VP & President of U.S.',
#      'yearBorn': 1972,
#      'fiscalYear': 2022,
#      'totalPay': 1240132,
#      'exercisedValue': 878894,
#      'unexercisedValue': 458061},
#     {'maxAge': 1,
#      'name': 'Ken  Cook',
#      'title': 'Investor Relations Officer',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Norman M. Brothers Jr.',
#      'age': 54,
#      'title': 'Executive VP, Chief Legal, Compliance Officer & Corporate Secretary',
#      'yearBorn': 1968,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Kevin M. Warren',
#      'age': 59,
#      'title': 'Executive VP and Chief Marketing & Customer Experience Officer',
#      'yearBorn': 1963,
#      'fiscalYear': 2022,
#      'totalPay': 1605669,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Darrell L. Ford',
#      'age': 57,
#      'title': 'Executive VP, Chief Diversity, Equity and Inclusion Officer & Chief Human Resources Officer',
#      'yearBorn': 1965,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Ralph  Ozoude',
#      'title': 'Managing Director of Nigerian Operations & Special Projects Manager for West Africa',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0}],
#    'auditRisk': 2,
#    'boardRisk': 7,
#    'compensationRisk': 8,
#    'shareHolderRightsRisk': 10,
#    'overallRisk': 9,
#    'governanceEpochDate': 1698796800,
#    'compensationAsOfEpochDate': 1672444800,
#    'maxAge': 86400,
#    'priceHint': 2,
#    'previousClose': 150.75,
#    'open': 151.17,
#    'dayLow': 150.7501,
#    'dayHigh': 152.04,
#    'regularMarketPreviousClose': 150.75,
#    'regularMarketOpen': 151.17,
#    'regularMarketDayLow': 150.7501,
#    'regularMarketDayHigh': 152.04,
#    'dividendRate': 6.48,
#    'dividendYield': 0.043,
#    'exDividendDate': 1699574400,
#    'payoutRatio': 0.6457,
#    'fiveYearAvgDividendYield': 3.02,
#    'beta': 1.103,
#    'trailingPE': 15.403242,
#    'forwardPE': 15.624872,
#    'volume': 1644358,
#    'regularMarketVolume': 1644358,
#    'averageVolume': 3618304,
#    'averageVolume10days': 3883570,
#    'averageDailyVolume10Day': 3883570,
#    'bid': 151.53,
#    'ask': 152.0,
#    'bidSize': 800,
#    'askSize': 1000,
#    'marketCap': 129518313472,
#    'fiftyTwoWeekLow': 133.68,
#    'fiftyTwoWeekHigh': 197.8,
#    'priceToSalesTrailing12Months': 1.3915628,
#    'fiftyDayAverage': 149.8356,
#    'twoHundredDayAverage': 171.71475,
#    'trailingAnnualDividendRate': 6.38,
#    'trailingAnnualDividendYield': 0.042321727,
#    'currency': 'USD',
#    'enterpriseValue': 147692240896,
#    'profitMargins': 0.09193,
#    'floatShares': 722773670,
#    'sharesOutstanding': 723257024,
#    'sharesShort': 10869532,
#    'sharesShortPriorMonth': 8385054,
#    'sharesShortPreviousMonthDate': 1695945600,
#    'dateShortInterest': 1698710400,
#    'sharesPercentSharesOut': 0.0128,
#    'heldPercentInsiders': 0.0001,
#    'heldPercentInstitutions': 0.72651,
#    'shortRatio': 2.95,
#    'shortPercentOfFloat': 0.015,
#    'impliedSharesOutstanding': 851926016,
#    'bookValue': 22.498,
#    'priceToBook': 6.7574897,
#    'lastFiscalYearEnd': 1672444800,
#    'nextFiscalYearEnd': 1703980800,
#    'mostRecentQuarter': 1696032000,
#    'earningsQuarterlyGrowth': -0.564,
#    'netIncomeToCommon': 8556000256,
#    'trailingEps': 9.87,
#    'forwardEps': 9.73,
#    'pegRatio': -3.59,
#    'enterpriseToRevenue': 1.587,
#    'enterpriseToEbitda': 11.067,
#    '52WeekChange': -0.17406315,
#    'SandP52WeekChange': 0.13176453,
#    'lastDividendValue': 1.62,
#    'lastDividendDate': 1699574400,
#    'exchange': 'NYQ',
#    'quoteType': 'EQUITY',
#    'symbol': 'UPS',
#    'underlyingSymbol': 'UPS',
#    'shortName': 'United Parcel Service, Inc.',
#    'longName': 'United Parcel Service, Inc.',
#    'firstTradeDateEpochUtc': 942244200,
#    'timeZoneFullName': 'America/New_York',
#    'timeZoneShortName': 'EST',
#    'uuid': '0e60ac85-bc39-31e2-a1d6-6a048ff164da',
#    'messageBoardId': 'finmb_238570',
#    'gmtOffSetMilliseconds': -18000000,
#    'currentPrice': 152.03,
#    'targetHighPrice': 220.0,
#    'targetLowPrice': 100.0,
#    'targetMeanPrice': 163.67,
#    'targetMedianPrice': 162.0,
#    'recommendationMean': 2.4,
#    'recommendationKey': 'buy',
#    'numberOfAnalystOpinions': 27,
#    'totalCash': 7278000128,
#    'totalCashPerShare': 8.543,
#    'ebitda': 13345000448,
#    'totalDebt': 25440000000,
#    'quickRatio': 1.073,
#    'currentRatio': 1.217,
#    'totalRevenue': 93073997824,
#    'debtToEquity': 132.638,
#    'revenuePerShare': 108.069,
#    'returnOnAssets': 0.08902001,
#    'returnOnEquity': 0.47313,
#    'grossProfits': 25086000000,
#    'freeCashflow': 4060750080,
#    'operatingCashflow': 11159000064,
#    'earningsGrowth': -0.557,
#    'revenueGrowth': -0.128,
#    'grossMargins': 0.23291999,
#    'ebitdaMargins': 0.14338,
#    'operatingMargins': 0.07136,
#    'financialCurrency': 'USD',
#    'trailingPegRatio': 2.9948},
#   'close':                  Close
#   Date
#   2023-01-03  237.662163
#   2023-01-04  242.181974
#   2023-01-05  234.424972
#   2023-01-06  242.654415
#   2023-01-09  244.104161
#   ...                ...
#   2023-10-24  204.396697
#   2023-10-25  201.905323
#   2023-10-26  190.769900
#   2023-10-27  186.254161
#   2023-10-30  192.396260
#
#   [208 rows x 1 columns],
#   'volume':               Volume
#   Date
#   2023-01-03   2206500
#   2023-01-04   1965100
#   2023-01-05   2736800
#   2023-01-06   3690100
#   2023-01-07         0
#   ...              ...
#   2023-10-26  10581400
#   2023-10-27   6594600
#   2023-10-28         0
#   2023-10-29         0
#   2023-10-30   5665500
#
#   [301 rows x 1 columns]},
#  {'ticker': 'USB',
#   'info': {'address1': '800 Nicollet Mall',
#    'city': 'Minneapolis',
#    'state': 'MN',
#    'zip': '55402',
#    'country': 'United States',
#    'phone': '866 775 9668',
#    'website': 'https://www.usbank.com',
#    'industry': 'Banks - Regional',
#    'industryKey': 'banks-regional',
#    'industryDisp': 'Banks - Regional',
#    'sector': 'Financial Services',
#    'sectorKey': 'financial-services',
#    'sectorDisp': 'Financial Services',
#    'longBusinessSummary': 'U.S. Bancorp, a financial services holding company, provides various financial services to individuals, businesses, institutional organizations, governmental entities and other financial institutions in the United States. It operates in Corporate and Commercial Banking, Consumer and Business Banking, Wealth Management and Investment Services, Payment Services, and Treasury and Corporate Support segments. The company offers depository services, including checking accounts, savings accounts, and time certificate contracts; lending services, such as traditional credit products; and credit card services, lease financing and import/export trade, asset-backed lending, agricultural finance, and other products. In addition, it provides ancillary services comprising capital markets, treasury management, and receivable lock-box collection services to corporate and governmental entity customers. Further, the company offers asset management and fiduciary services for individuals, estates, foundations, business corporations, and charitable organizations. Additionally, it provides investment and insurance products to its customers principally within its markets, as well as fund administration services to mutual and other funds. Furthermore, the company provides corporate and purchasing card, and corporate trust services. The company offers merchant processing, investment management, ATM processing, mortgage banking, insurance, and brokerage and leasing services. U.S. Bancorp was founded in 1863 and is headquartered in Minneapolis, Minnesota.',
#    'fullTimeEmployees': 75000,
#    'companyOfficers': [{'maxAge': 1,
#      'name': 'Mr. Andrew J. Cecere',
#      'age': 61,
#      'title': 'Chairman, President & CEO',
#      'yearBorn': 1961,
#      'fiscalYear': 2022,
#      'totalPay': 6157514,
#      'exercisedValue': 808561,
#      'unexercisedValue': 885808},
#     {'maxAge': 1,
#      'name': 'Mr. Terrance Robert Dolan',
#      'age': 60,
#      'title': 'Chief Administration Officer & Vice Chair',
#      'yearBorn': 1962,
#      'fiscalYear': 2022,
#      'totalPay': 2628538,
#      'exercisedValue': 0,
#      'unexercisedValue': 245805},
#     {'maxAge': 1,
#      'name': 'Mr. Jeffry H. von Gillern',
#      'age': 56,
#      'title': 'Advisor',
#      'yearBorn': 1966,
#      'fiscalYear': 2022,
#      'totalPay': 2276512,
#      'exercisedValue': 271838,
#      'unexercisedValue': 271754},
#     {'maxAge': 1,
#      'name': 'Ms. Gunjan  Kedia',
#      'age': 51,
#      'title': 'Vice Chairman of Wealth, Corporate, Commercial & Institutional Banking',
#      'yearBorn': 1971,
#      'fiscalYear': 2022,
#      'totalPay': 2297837,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Timothy A. Welsh',
#      'age': 56,
#      'title': 'Vice Chairman of Consumer & Business Banking',
#      'yearBorn': 1966,
#      'fiscalYear': 2022,
#      'totalPay': 2177425,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. John C. Stern',
#      'age': 43,
#      'title': 'Senior Executive VP & CFO',
#      'yearBorn': 1979,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Souheil S. Badran',
#      'age': 57,
#      'title': 'Senior EVP & COO',
#      'yearBorn': 1965,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Ms. Jennifer Ann Thompson C.F.A.',
#      'title': 'EVP, Head of Corporate Finance and Director of Investor Relations & Economic Analysis',
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. Dilip  Venkatachari',
#      'age': 62,
#      'title': 'Senior EVP and Chief Information & Technology Officer',
#      'yearBorn': 1960,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0},
#     {'maxAge': 1,
#      'name': 'Mr. James L. Chosy',
#      'age': 58,
#      'title': 'Senior EVP, Corporate Secretary & General Counsel',
#      'yearBorn': 1964,
#      'fiscalYear': 2022,
#      'exercisedValue': 0,
#      'unexercisedValue': 0}],
#    'auditRisk': 4,
#    'boardRisk': 3,
#    'compensationRisk': 2,
#    'shareHolderRightsRisk': 6,
#    'overallRisk': 3,
#    'governanceEpochDate': 1698796800,
#    'compensationAsOfEpochDate': 1672444800,
#    'maxAge': 86400,
#    'priceHint': 2,
#    'previousClose': 36.83,
#    'open': 36.8,
#    'dayLow': 36.67,
#    'dayHigh': 37.365,
#    'regularMarketPreviousClose': 36.83,
#    'regularMarketOpen': 36.8,
#    'regularMarketDayLow': 36.67,
#    'regularMarketDayHigh': 37.365,
#    'dividendRate': 1.92,
#    'dividendYield': 0.0521,
#    'exDividendDate': 1695859200,
#    'payoutRatio': 0.57310003,
#    'fiveYearAvgDividendYield': 3.72,
#    'beta': 1.042,
#    'trailingPE': 11.104478,
#    'forwardPE': 9.346734,
#    'volume': 2796765,
#    'regularMarketVolume': 2796765,
#    'averageVolume': 11974655,
#    'averageVolume10days': 8159900,
#    'averageDailyVolume10Day': 8159900,
#    'bid': 37.19,
#    'ask': 37.25,
#    'bidSize': 900,
#    'askSize': 900,
#    'marketCap': 57920774144,
#    'fiftyTwoWeekLow': 27.27,
#    'fiftyTwoWeekHigh': 49.95,
#    'priceToSalesTrailing12Months': 2.3546946,
#    'fiftyDayAverage': 33.567,
#    'twoHundredDayAverage': 35.7179,
#    'trailingAnnualDividendRate': 1.92,
#    'trailingAnnualDividendYield': 0.05213141,
#    'currency': 'USD',
#    'enterpriseValue': 70205857792,
#    'profitMargins': 0.22388001,
#    'floatShares': 1553088735,
#    'sharesOutstanding': 1557010048,
#    'sharesShort': 30738249,
#    'sharesShortPriorMonth': 38074358,
#    'sharesShortPreviousMonthDate': 1695945600,
#    'dateShortInterest': 1698710400,
#    'sharesPercentSharesOut': 0.0197,
#    'heldPercentInsiders': 0.00149,
#    'heldPercentInstitutions': 0.77252996,
#    'shortRatio': 2.26,
#    'shortPercentOfFloat': 0.0198,
#    'impliedSharesOutstanding': 1557010048,
#    'bookValue': 29.74,
#    'priceToBook': 1.2508407,
#    'lastFiscalYearEnd': 1672444800,
#    'nextFiscalYearEnd': 1703980800,
#    'mostRecentQuarter': 1696032000,
#    'earningsQuarterlyGrowth': -0.159,
#    'netIncomeToCommon': 5137999872,
#    'trailingEps': 3.35,
#    'forwardEps': 3.98,
#    'pegRatio': 1.42,
#    'lastSplitFactor': '3:1',
#    'lastSplitDate': 924220800,
#    'enterpriseToRevenue': 2.854,
#    '52WeekChange': -0.16787165,
#    'SandP52WeekChange': 0.13176453,
#    'lastDividendValue': 0.48,
#    'lastDividendDate': 1695859200,
#    'exchange': 'NYQ',
#    'quoteType': 'EQUITY',
#    'symbol': 'USB',
#    'underlyingSymbol': 'USB',
#    'shortName': 'U.S. Bancorp',
#    'longName': 'U.S. Bancorp',
#    'firstTradeDateEpochUtc': 105283800,
#    'timeZoneFullName': 'America/New_York',
#    'timeZoneShortName': 'EST',
#    'uuid': '7aca5ec6-18f7-3173-a8dc-d7014cf9bdcf',
#    'messageBoardId': 'finmb_305304',
#    'gmtOffSetMilliseconds': -18000000,
#    'currentPrice': 37.2,
#    'targetHighPrice': 63.0,
#    'targetLowPrice': 31.0,
#    'targetMeanPrice': 40.44,
#    'targetMedianPrice': 38.5,
#    'recommendationMean': 2.3,
#    'recommendationKey': 'buy',
#    'numberOfAnalystOpinions': 22,
#    'totalCash': 67476000768,
#    'totalCashPerShare': 43.337,
#    'totalDebt': 72488001536,
#    'totalRevenue': 24597999616,
#    'revenuePerShare': 16.09,
#    'returnOnAssets': 0.00871,
#    'returnOnEquity': 0.10885,
#    'grossProfits': 22142000000,
#    'operatingCashflow': 14919000064,
#    'earningsGrowth': -0.213,
#    'revenueGrowth': 0.093,
#    'grossMargins': 0.0,
#    'ebitdaMargins': 0.0,
#    'operatingMargins': 0.37008,
#    'financialCurrency': 'USD',
#    'trailingPegRatio': 2.506},
#   'close':                 Close
#   Date
#   2023-01-03  60.527378
#   2023-01-04  62.941877
#   2023-01-05  61.586449
#   2023-01-06  62.795901
#   2023-01-09  62.621470
#   ...               ...
#   2023-10-24  42.968202
#   2023-10-25  42.997469
#   2023-10-26  43.851816
#   2023-10-27  42.326094
#   2023-10-30  43.406304
#
#   [208 rows x 1 columns],
#   'volume':               Volume
#   Date
#   2023-01-03  12795900
#   2023-01-04  16338400
#   2023-01-05   8364000
#   2023-01-06   8198300
#   2023-01-07         0
#   ...              ...
#   2023-10-26  15956600
#   2023-10-27  10909400
#   2023-10-28         0
#   2023-10-29         0
#   2023-10-30   9653000
#
#   [301 rows x 1 columns]}]

# %%
#returns a list of industries 
def return_industry(tickers):
    industries = []
    for i in range (len (tickers)):
        stock = tickers[i]
        sector = stock["info"]['sector']
        industries.append(sector)
    return industries

list_of_industries = return_industry(filtered_list)

#returns a dictionary of sectors and how many companies are in the sector from a list of industries
def industry_count(industry_list):
    industry_dict={}
    while len(industry_list) > 0:
        industry_dict[industry_list[0]] = industry_list.count(industry_list[0])
        industry_list = remove_items(industry_list, industry_list[0])
    return industry_dict

#Used to remove existing industries
def remove_items(lst, item): 
    resulting_list = [i for i in lst if i != item] 
    return resulting_list

count_of_industries = industry_count(list_of_industries)

#Sorts the dictionary of industries by descending number of stocks in the industry
sorted_dict_of_industries = sorted(count_of_industries.items(),key=lambda x:x[1], reverse = True)

# %%
#creating a dictionary of stocks within the given industry
def stocks_in_industry (industry_dict):
    industry_portfolio = {}
    for i in range (len (industry_dict)):
        industry_portfolio[(industry_dict[i][0])] = stock_grouper(filtered_list, (industry_dict[i][0]))
    return industry_portfolio

#finds all stocks in the given industry and returns it in a list
def stock_grouper (stock_list, industry):
    stocks = []
    for i in range (len (stock_list)):
        stock = stock_list[i]
        sector = stock["info"]['sector']
        if sector == industry:
            stocks.append(stock)
    return stocks
            
stocks_in_industry_list = stocks_in_industry(sorted_dict_of_industries)      

stocks_in_industry_list
# Out:
# {'Financial Services': [{'ticker': 'AIG',
#    'info': {'address1': '1271 Avenue of the Americas',
#     'city': 'New York',
#     'state': 'NY',
#     'zip': '10020',
#     'country': 'United States',
#     'phone': '212 770 7000',
#     'website': 'https://www.aig.com',
#     'industry': 'Insurance - Diversified',
#     'industryKey': 'insurance-diversified',
#     'industryDisp': 'Insurance - Diversified',
#     'sector': 'Financial Services',
#     'sectorKey': 'financial-services',
#     'sectorDisp': 'Financial Services',
#     'longBusinessSummary': "American International Group, Inc. offers insurance products for commercial, institutional, and individual customers in North America and internationally. It operates through General Insurance, and Life and Retirement segments. The General Insurance segment provides commercial and industrial property insurance, including business interruption and package insurance that cover exposure to made and natural disasters; general liability, environmental, commercial automobile liability, workers' compensation, excess casualty, and crisis management insurance products; and professional liability insurance. This segment also offers marine, energy-related property insurance, aviation, political risk, trade credit, trade finance, and portfolio solutions, as well as operates reinsurance business; voluntary and sponsor-paid personal accident, and supplemental health products; and personal auto and personal property insurance. The Life and Retirement segment offers individual retirement products, including variable, fixed index, and fixed annuities, as well as retail mutual funds; group retirement products comprising record-keeping, plan administrative and compliance services, financial planning, and advisory solutions; life insurance, including term and universal life insurance; and institutional markets products, which includes wrap products, structured settlement, pension risk transfer annuities, corporate and bank-owned life insurance, high net worth, and guaranteed investment contract products. The company distributes its products through a network of brokers, agents, advisors, banks, and other distributors. American International Group, Inc. was founded in 1919 and is headquartered in New York, New York.",
#     'fullTimeEmployees': 26200,
#     'companyOfficers': [{'maxAge': 1,
#       'name': 'Mr. Peter Salvatore Zaffino',
#       'age': 55,
#       'title': 'Chairman, CEO & President',
#       'yearBorn': 1967,
#       'fiscalYear': 2022,
#       'totalPay': 9666320,
#       'exercisedValue': 0,
#       'unexercisedValue': 5864164},
#      {'maxAge': 1,
#       'name': 'Mr. David Hughes McElroy',
#       'age': 63,
#       'title': 'Executive VP & CEO of General Insurance',
#       'yearBorn': 1959,
#       'fiscalYear': 2022,
#       'totalPay': 5193619,
#       'exercisedValue': 0,
#       'unexercisedValue': 1944637},
#      {'maxAge': 1,
#       'name': 'Mr. Kevin Timothy Hogan',
#       'age': 60,
#       'title': 'President & CEO of Corebridge Financial, Inc.',
#       'yearBorn': 1962,
#       'fiscalYear': 2022,
#       'totalPay': 3740420,
#       'exercisedValue': 0,
#       'unexercisedValue': 3244787},
#      {'maxAge': 1,
#       'name': 'Ms. Sabra Rose Purtill C.F.A.',
#       'age': 59,
#       'title': 'Executive VP & CFO',
#       'yearBorn': 1963,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Claude E. Wade',
#       'age': 54,
#       'title': 'Executive VP, Head of Global Business Operations & IT and Chief Digital Officer',
#       'yearBorn': 1968,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Elaine Ann Rocha',
#       'age': 49,
#       'title': 'Global Chief Investment Officer',
#       'yearBorn': 1973,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Kathleen  Carbone',
#       'age': 50,
#       'title': 'VP & Chief Accounting Officer',
#       'yearBorn': 1972,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. John P. Repko',
#       'age': 59,
#       'title': 'Executive VP & Chief Information Officer',
#       'yearBorn': 1963,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Quentin John McMillan',
#       'title': 'VP, MD & Head of Investor Relations',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Karen  Nelson',
#       'title': 'Chief Compliance Officer',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0}],
#     'auditRisk': 3,
#     'boardRisk': 1,
#     'compensationRisk': 1,
#     'shareHolderRightsRisk': 5,
#     'overallRisk': 1,
#     'governanceEpochDate': 1698796800,
#     'compensationAsOfEpochDate': 1672444800,
#     'maxAge': 86400,
#     'priceHint': 2,
#     'previousClose': 64.97,
#     'open': 65.1,
#     'dayLow': 65.02,
#     'dayHigh': 65.72,
#     'regularMarketPreviousClose': 64.97,
#     'regularMarketOpen': 65.1,
#     'regularMarketDayLow': 65.02,
#     'regularMarketDayHigh': 65.72,
#     'dividendRate': 1.44,
#     'dividendYield': 0.0222,
#     'exDividendDate': 1702425600,
#     'payoutRatio': 0.2361,
#     'fiveYearAvgDividendYield': 2.77,
#     'beta': 1.049,
#     'trailingPE': 11.32118,
#     'forwardPE': 8.602902,
#     'volume': 1424101,
#     'regularMarketVolume': 1424101,
#     'averageVolume': 3107095,
#     'averageVolume10days': 3099460,
#     'averageDailyVolume10Day': 3099460,
#     'bid': 65.21,
#     'ask': 65.95,
#     'bidSize': 900,
#     'askSize': 1200,
#     'marketCap': 45780029440,
#     'fiftyTwoWeekLow': 45.66,
#     'fiftyTwoWeekHigh': 65.72,
#     'priceToSalesTrailing12Months': 0.9128438,
#     'fiftyDayAverage': 61.9072,
#     'twoHundredDayAverage': 57.50955,
#     'trailingAnnualDividendRate': 1.36,
#     'trailingAnnualDividendYield': 0.020932738,
#     'currency': 'USD',
#     'enterpriseValue': 58511052800,
#     'profitMargins': 0.082770005,
#     'floatShares': 700601160,
#     'sharesOutstanding': 702040000,
#     'sharesShort': 5926896,
#     'sharesShortPriorMonth': 6614539,
#     'sharesShortPreviousMonthDate': 1695945600,
#     'dateShortInterest': 1698710400,
#     'sharesPercentSharesOut': 0.0084,
#     'heldPercentInsiders': 0.00319,
#     'heldPercentInstitutions': 0.91947,
#     'shortRatio': 1.96,
#     'shortPercentOfFloat': 0.0095,
#     'impliedSharesOutstanding': 702040000,
#     'bookValue': 56.061,
#     'priceToBook': 1.1631972,
#     'lastFiscalYearEnd': 1672444800,
#     'nextFiscalYearEnd': 1703980800,
#     'mostRecentQuarter': 1696032000,
#     'earningsQuarterlyGrowth': -0.262,
#     'netIncomeToCommon': 4121999872,
#     'trailingEps': 5.76,
#     'forwardEps': 7.58,
#     'pegRatio': 0.61,
#     'lastSplitFactor': '1:20',
#     'lastSplitDate': 1246406400,
#     'enterpriseToRevenue': 1.167,
#     'enterpriseToEbitda': 4.951,
#     '52WeekChange': 0.06368697,
#     'SandP52WeekChange': 0.13176453,
#     'lastDividendValue': 0.36,
#     'lastDividendDate': 1694649600,
#     'exchange': 'NYQ',
#     'quoteType': 'EQUITY',
#     'symbol': 'AIG',
#     'underlyingSymbol': 'AIG',
#     'shortName': 'American International Group, I',
#     'longName': 'American International Group, Inc.',
#     'firstTradeDateEpochUtc': 94833000,
#     'timeZoneFullName': 'America/New_York',
#     'timeZoneShortName': 'EST',
#     'uuid': '00364109-56c8-328a-a91c-6092045edb5f',
#     'messageBoardId': 'finmb_250388',
#     'gmtOffSetMilliseconds': -18000000,
#     'currentPrice': 65.21,
#     'targetHighPrice': 83.0,
#     'targetLowPrice': 67.0,
#     'targetMeanPrice': 73.0,
#     'targetMedianPrice': 72.0,
#     'recommendationMean': 2.1,
#     'recommendationKey': 'buy',
#     'numberOfAnalystOpinions': 15,
#     'totalCash': 15038000128,
#     'totalCashPerShare': 21.42,
#     'ebitda': 11816999936,
#     'totalDebt': 24054999040,
#     'quickRatio': 0.2,
#     'currentRatio': 0.845,
#     'totalRevenue': 50150998016,
#     'debtToEquity': 55.666,
#     'revenuePerShare': 68.663,
#     'returnOnAssets': 0.00843,
#     'returnOnEquity': 0.11637,
#     'grossProfits': 24968000000,
#     'freeCashflow': 1659250048,
#     'operatingCashflow': 4861000192,
#     'earningsGrowth': -0.208,
#     'revenueGrowth': -0.09,
#     'grossMargins': 0.31086,
#     'ebitdaMargins': 0.23562999,
#     'operatingMargins': 0.306,
#     'financialCurrency': 'USD',
#     'trailingPegRatio': None},
#    'close':                 Close
#    Date
#    2023-01-03  85.326792
#    2023-01-04  87.322799
#    2023-01-05  85.643867
#    2023-01-06  87.529162
#    2023-01-09  85.810624
#    ...               ...
#    2023-10-24  81.953050
#    2023-10-25  83.768794
#    2023-10-26  83.990649
#    2023-10-27  82.234739
#    2023-10-30  84.566738
#
#    [208 rows x 1 columns],
#    'volume':              Volume
#    Date
#    2023-01-03  3363500
#    2023-01-04  3763600
#    2023-01-05  3902300
#    2023-01-06  2893400
#    2023-01-07        0
#    ...             ...
#    2023-10-26  2788200
#    2023-10-27  3097600
#    2023-10-28        0
#    2023-10-29        0
#    2023-10-30  3075900
#
#    [301 rows x 1 columns]},
#   {'ticker': 'AXP',
#    'info': {'address1': '200 Vesey Street',
#     'city': 'New York',
#     'state': 'NY',
#     'zip': '10285',
#     'country': 'United States',
#     'phone': '212 640 2000',
#     'website': 'https://www.americanexpress.com',
#     'industry': 'Credit Services',
#     'industryKey': 'credit-services',
#     'industryDisp': 'Credit Services',
#     'sector': 'Financial Services',
#     'sectorKey': 'financial-services',
#     'sectorDisp': 'Financial Services',
#     'longBusinessSummary': "American Express Company, together with its subsidiaries, provides charge and credit payment card products, and travel-related services worldwide. The company operates through three segments: Global Consumer Services Group, Global Commercial Services, and Global Merchant and Network Services. Its products and services include payment and financing products; network services; accounts payable expense management products and services; and travel and lifestyle services. The company's products and services also comprise merchant acquisition and processing, servicing and settlement, point-of-sale marketing, and information products and services for merchants; and fraud prevention services, as well as the design and operation of customer loyalty programs. It sells its products and services to consumers, small businesses, mid-sized companies, and large corporations through mobile and online applications, third-party vendors and business partners, direct mail, telephone, in-house sales teams, and direct response advertising. American Express Company was founded in 1850 and is headquartered in New York, New York.",
#     'fullTimeEmployees': 77300,
#     'companyOfficers': [{'maxAge': 1,
#       'name': 'Mr. Stephen Joseph Squeri',
#       'age': 62,
#       'title': 'Chairman & CEO',
#       'yearBorn': 1960,
#       'fiscalYear': 2022,
#       'totalPay': 12391509,
#       'exercisedValue': 22554032,
#       'unexercisedValue': 8181222},
#      {'maxAge': 1,
#       'name': 'Mr. Ravikumar  Radhakrishnan',
#       'age': 50,
#       'title': 'Executive VP & CIO',
#       'yearBorn': 1972,
#       'fiscalYear': 2022,
#       'totalPay': 7427926,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Anre D. Williams',
#       'age': 56,
#       'title': 'CEO of American Express National Bank & Group President of Enterprise Services',
#       'yearBorn': 1966,
#       'fiscalYear': 2022,
#       'totalPay': 7208480,
#       'exercisedValue': 14110758,
#       'unexercisedValue': 1641721},
#      {'maxAge': 1,
#       'name': 'Mr. Douglas E. Buckminster',
#       'age': 61,
#       'title': 'Vice Chairman',
#       'yearBorn': 1961,
#       'fiscalYear': 2022,
#       'totalPay': 8514716,
#       'exercisedValue': 1550017,
#       'unexercisedValue': 14540464},
#      {'maxAge': 1,
#       'name': 'Mr. Christophe  Le Caillec',
#       'age': 56,
#       'title': 'Chief Financial Officer',
#       'yearBorn': 1966,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Jessica  Lieberman Quinn',
#       'age': 49,
#       'title': 'Executive VP, Corporate Controller & Principal Accounting Officer',
#       'yearBorn': 1973,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Kerri S. Bernstein',
#       'title': 'Head of Investor Relations',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Laureen E. Seeger',
#       'age': 60,
#       'title': 'Chief Legal Officer',
#       'yearBorn': 1962,
#       'fiscalYear': 2022,
#       'totalPay': 5886810,
#       'exercisedValue': 1388148,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. David B. Nigro',
#       'age': 60,
#       'title': 'Chief Risk Officer & Head of Global Risk and Compliance',
#       'yearBorn': 1962,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Elizabeth  Rutledge',
#       'age': 60,
#       'title': 'Chief Marketing Officer',
#       'yearBorn': 1962,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0}],
#     'auditRisk': 5,
#     'boardRisk': 6,
#     'compensationRisk': 10,
#     'shareHolderRightsRisk': 6,
#     'overallRisk': 9,
#     'governanceEpochDate': 1698796800,
#     'compensationAsOfEpochDate': 1672444800,
#     'maxAge': 86400,
#     'priceHint': 2,
#     'previousClose': 163.79,
#     'open': 164.56,
#     'dayLow': 163.97,
#     'dayHigh': 165.22,
#     'regularMarketPreviousClose': 163.79,
#     'regularMarketOpen': 164.56,
#     'regularMarketDayLow': 163.97,
#     'regularMarketDayHigh': 165.22,
#     'dividendRate': 2.4,
#     'dividendYield': 0.0147,
#     'exDividendDate': 1696464000,
#     'payoutRatio': 0.2662,
#     'fiveYearAvgDividendYield': 1.33,
#     'beta': 1.206,
#     'trailingPE': 15.424015,
#     'forwardPE': 13.334955,
#     'volume': 891843,
#     'regularMarketVolume': 891843,
#     'averageVolume': 3041174,
#     'averageVolume10days': 2739080,
#     'averageDailyVolume10Day': 2739080,
#     'bid': 164.26,
#     'ask': 164.25,
#     'bidSize': 800,
#     'askSize': 800,
#     'marketCap': 119820410880,
#     'fiftyTwoWeekLow': 140.91,
#     'fiftyTwoWeekHigh': 182.15,
#     'priceToSalesTrailing12Months': 2.2034316,
#     'fiftyDayAverage': 152.176,
#     'twoHundredDayAverage': 161.7619,
#     'trailingAnnualDividendRate': 2.32,
#     'trailingAnnualDividendYield': 0.014164479,
#     'currency': 'USD',
#     'enterpriseValue': 123860344832,
#     'profitMargins': 0.14735,
#     'floatShares': 575789168,
#     'sharesOutstanding': 728745984,
#     'sharesShort': 6242430,
#     'sharesShortPriorMonth': 6282419,
#     'sharesShortPreviousMonthDate': 1695945600,
#     'dateShortInterest': 1698710400,
#     'sharesPercentSharesOut': 0.0086,
#     'heldPercentInsiders': 0.0014399999,
#     'heldPercentInstitutions': 0.86319,
#     'shortRatio': 1.81,
#     'shortPercentOfFloat': 0.0108,
#     'impliedSharesOutstanding': 728745984,
#     'bookValue': 37.481,
#     'priceToBook': 4.386756,
#     'lastFiscalYearEnd': 1672444800,
#     'nextFiscalYearEnd': 1703980800,
#     'mostRecentQuarter': 1696032000,
#     'earningsQuarterlyGrowth': 0.304,
#     'netIncomeToCommon': 7894000128,
#     'trailingEps': 10.66,
#     'forwardEps': 12.33,
#     'pegRatio': 1.02,
#     'lastSplitFactor': '10000:8753',
#     'lastSplitDate': 1128297600,
#     'enterpriseToRevenue': 2.278,
#     '52WeekChange': 0.06253648,
#     'SandP52WeekChange': 0.13176453,
#     'lastDividendValue': 0.6,
#     'lastDividendDate': 1696464000,
#     'exchange': 'NYQ',
#     'quoteType': 'EQUITY',
#     'symbol': 'AXP',
#     'underlyingSymbol': 'AXP',
#     'shortName': 'American Express Company',
#     'longName': 'American Express Company',
#     'firstTradeDateEpochUtc': 76253400,
#     'timeZoneFullName': 'America/New_York',
#     'timeZoneShortName': 'EST',
#     'uuid': '3b2d1661-0aa2-3fea-bdbf-6a46a3a4a87c',
#     'messageBoardId': 'finmb_92001',
#     'gmtOffSetMilliseconds': -18000000,
#     'currentPrice': 164.42,
#     'targetHighPrice': 201.0,
#     'targetLowPrice': 125.0,
#     'targetMeanPrice': 171.85,
#     'targetMedianPrice': 175.1,
#     'recommendationMean': 2.4,
#     'recommendationKey': 'buy',
#     'numberOfAnalystOpinions': 25,
#     'totalCash': 44073000960,
#     'totalCashPerShare': 60.478,
#     'totalDebt': 48113000448,
#     'quickRatio': 1.629,
#     'currentRatio': 1.632,
#     'totalRevenue': 54378999808,
#     'debtToEquity': 176.083,
#     'revenuePerShare': 73.436,
#     'returnOnAssets': 0.03443,
#     'returnOnEquity': 0.31261998,
#     'grossProfits': 28776000000,
#     'operatingCashflow': 20221999104,
#     'earningsGrowth': 0.336,
#     'revenueGrowth': 0.107,
#     'grossMargins': 0.55912995,
#     'ebitdaMargins': 0.0,
#     'operatingMargins': 0.22003001,
#     'financialCurrency': 'USD',
#     'trailingPegRatio': 1.0159},
#    'close':                  Close
#    Date
#    2023-01-03  199.480012
#    2023-01-04  205.849882
#    2023-01-05  197.462308
#    2023-01-06  203.629023
#    2023-01-09  202.065407
#    ...                ...
#    2023-10-24  197.689320
#    2023-10-25  197.219453
#    2023-10-26  197.850774
#    2023-10-27  195.205627
#    2023-10-30  198.620934
#
#    [208 rows x 1 columns],
#    'volume':              Volume
#    Date
#    2023-01-03  2762200
#    2023-01-04  2620400
#    2023-01-05  2505700
#    2023-01-06  3077400
#    2023-01-07        0
#    ...             ...
#    2023-10-26  3378000
#    2023-10-27  3442500
#    2023-10-28        0
#    2023-10-29        0
#    2023-10-30  3303300
#
#    [301 rows x 1 columns]},
#   {'ticker': 'BAC',
#    'info': {'address1': 'Bank of America Corporate Center',
#     'address2': '100 North Tryon Street',
#     'city': 'Charlotte',
#     'state': 'NC',
#     'zip': '28255',
#     'country': 'United States',
#     'phone': '704 386 5681',
#     'website': 'https://www.bankofamerica.com',
#     'industry': 'Banks - Diversified',
#     'industryKey': 'banks-diversified',
#     'industryDisp': 'Banks - Diversified',
#     'sector': 'Financial Services',
#     'sectorKey': 'financial-services',
#     'sectorDisp': 'Financial Services',
#     'longBusinessSummary': "Bank of America Corporation, through its subsidiaries, provides banking and financial products and services for individual consumers, small and middle-market businesses, institutional investors, large corporations, and governments worldwide. Its Consumer Banking segment offers traditional and money market savings accounts, certificates of deposit and IRAs, noninterest-and interest-bearing checking accounts, and investment accounts and products; and credit and debit cards, residential mortgages, and home equity loans, as well as direct and indirect loans, such as automotive, recreational vehicle, and consumer personal loans. The company's Global Wealth & Investment Management segment offers investment management, brokerage, banking, and trust and retirement products and services; and wealth management solutions, as well as customized solutions, including specialty asset management services. Its Global Banking segment provides lending products and services, including commercial loans, leases, commitment facilities, trade finance, and commercial real estate and asset-based lending; treasury solutions, such as treasury management, foreign exchange, and short-term investing options and merchant services; working capital management solutions; and debt and equity underwriting and distribution, and merger-related and other advisory services. The company's Global Markets segment offers market-making, financing, securities clearing, settlement, and custody services, as well as risk management products using interest rate, equity, credit, currency and commodity derivatives, foreign exchange, fixed-income, and mortgage-related products. The company was founded in 1784 and is based in Charlotte, North Carolina.",
#     'fullTimeEmployees': 213000,
#     'companyOfficers': [{'maxAge': 1,
#       'name': 'Mr. Brian Thomas Moynihan',
#       'age': 63,
#       'title': 'Chairman, CEO & President',
#       'yearBorn': 1959,
#       'fiscalYear': 2022,
#       'totalPay': 1975176,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Alastair M. Borthwick',
#       'age': 53,
#       'title': 'Chief Financial Officer',
#       'yearBorn': 1969,
#       'fiscalYear': 2022,
#       'totalPay': 4844808,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Dean C. Athanasia',
#       'age': 55,
#       'title': 'President of Regional Banking',
#       'yearBorn': 1967,
#       'fiscalYear': 2022,
#       'totalPay': 6209621,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Paul M. Donofrio',
#       'age': 62,
#       'title': 'Vice Chairman',
#       'yearBorn': 1960,
#       'fiscalYear': 2022,
#       'totalPay': 6219903,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Geoffrey S. Greener',
#       'age': 57,
#       'title': 'Chief Risk Officer',
#       'yearBorn': 1965,
#       'fiscalYear': 2022,
#       'totalPay': 6210194,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Thomas M. Scrivener',
#       'age': 50,
#       'title': 'Chief Operations Executive',
#       'yearBorn': 1972,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Christopher M. Hyzy',
#       'title': 'Chief Investment Officer',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Rudolf A. Bless',
#       'title': 'Chief Accounting Officer',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Matthew M. Koder',
#       'age': 50,
#       'title': 'President of Global Corporate & Investment Banking',
#       'yearBorn': 1972,
#       'fiscalYear': 2022,
#       'totalPay': 9191389,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Aditya  Bhasin',
#       'age': 48,
#       'title': 'Chief Technology & Information Officer',
#       'yearBorn': 1974,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0}],
#     'auditRisk': 2,
#     'boardRisk': 7,
#     'compensationRisk': 10,
#     'shareHolderRightsRisk': 1,
#     'overallRisk': 7,
#     'governanceEpochDate': 1698796800,
#     'compensationAsOfEpochDate': 1672444800,
#     'maxAge': 86400,
#     'priceHint': 2,
#     'previousClose': 29.63,
#     'open': 29.48,
#     'dayLow': 29.48,
#     'dayHigh': 29.89,
#     'regularMarketPreviousClose': 29.63,
#     'regularMarketOpen': 29.48,
#     'regularMarketDayLow': 29.48,
#     'regularMarketDayHigh': 29.89,
#     'dividendRate': 0.96,
#     'dividendYield': 0.0324,
#     'exDividendDate': 1701302400,
#     'payoutRatio': 0.2521,
#     'fiveYearAvgDividendYield': 2.34,
#     'beta': 1.389,
#     'trailingPE': 8.327731,
#     'forwardPE': 9.119632,
#     'volume': 15303691,
#     'regularMarketVolume': 15303691,
#     'averageVolume': 45452461,
#     'averageVolume10days': 41255750,
#     'averageDailyVolume10Day': 41255750,
#     'bid': 29.7,
#     'ask': 29.78,
#     'bidSize': 3000,
#     'askSize': 3000,
#     'marketCap': 235275190272,
#     'fiftyTwoWeekLow': 24.96,
#     'fiftyTwoWeekHigh': 37.87,
#     'priceToSalesTrailing12Months': 2.4312322,
#     'fiftyDayAverage': 27.4768,
#     'twoHundredDayAverage': 29.2319,
#     'trailingAnnualDividendRate': 0.9,
#     'trailingAnnualDividendYield': 0.03037462,
#     'currency': 'USD',
#     'enterpriseValue': 92929253376,
#     'profitMargins': 0.3152,
#     'floatShares': 7887695836,
#     'sharesOutstanding': 7913730048,
#     'sharesShort': 70963864,
#     'sharesShortPriorMonth': 61268519,
#     'sharesShortPreviousMonthDate': 1695945600,
#     'dateShortInterest': 1698710400,
#     'sharesPercentSharesOut': 0.009,
#     'heldPercentInsiders': 0.0011100001,
#     'heldPercentInstitutions': 0.70398,
#     'shortRatio': 1.27,
#     'shortPercentOfFloat': 0.010299999,
#     'impliedSharesOutstanding': 7913730048,
#     'bookValue': 32.646,
#     'priceToBook': 0.91067815,
#     'lastFiscalYearEnd': 1672444800,
#     'nextFiscalYearEnd': 1703980800,
#     'mostRecentQuarter': 1696032000,
#     'earningsQuarterlyGrowth': 0.102,
#     'netIncomeToCommon': 28931999744,
#     'trailingEps': 3.57,
#     'forwardEps': 3.26,
#     'pegRatio': 2.19,
#     'lastSplitFactor': '2:1',
#     'lastSplitDate': 1093824000,
#     'enterpriseToRevenue': 0.96,
#     '52WeekChange': -0.21405834,
#     'SandP52WeekChange': 0.13176453,
#     'lastDividendValue': 0.24,
#     'lastDividendDate': 1693440000,
#     'exchange': 'NYQ',
#     'quoteType': 'EQUITY',
#     'symbol': 'BAC',
#     'underlyingSymbol': 'BAC',
#     'shortName': 'Bank of America Corporation',
#     'longName': 'Bank of America Corporation',
#     'firstTradeDateEpochUtc': 99153000,
#     'timeZoneFullName': 'America/New_York',
#     'timeZoneShortName': 'EST',
#     'uuid': 'bcf30d7f-4abd-3593-b752-cacd38ff491c',
#     'messageBoardId': 'finmb_19049',
#     'gmtOffSetMilliseconds': -18000000,
#     'currentPrice': 29.73,
#     'targetHighPrice': 51.0,
#     'targetLowPrice': 27.5,
#     'targetMeanPrice': 33.86,
#     'targetMedianPrice': 33.0,
#     'recommendationMean': 2.5,
#     'recommendationKey': 'buy',
#     'numberOfAnalystOpinions': 25,
#     'totalCash': 860959014912,
#     'totalCashPerShare': 108.793,
#     'totalDebt': 690215976960,
#     'totalRevenue': 96771997696,
#     'revenuePerShare': 12.017,
#     'returnOnAssets': 0.0098,
#     'returnOnEquity': 0.109610006,
#     'grossProfits': 92407000000,
#     'operatingCashflow': 43256000512,
#     'earningsGrowth': 0.111,
#     'revenueGrowth': 0.014,
#     'grossMargins': 0.0,
#     'ebitdaMargins': 0.0,
#     'operatingMargins': 0.33824003,
#     'financialCurrency': 'USD',
#     'trailingPegRatio': 6.8652},
#    'close':                 Close
#    Date
#    2023-01-03  45.436209
#    2023-01-04  46.683374
#    2023-01-05  45.943735
#    2023-01-06  46.659617
#    2023-01-09  45.531894
#    ...               ...
#    2023-10-24  34.864609
#    2023-10-25  35.109788
#    2023-10-26  36.053178
#    2023-10-27  34.769838
#    2023-10-30  35.615075
#
#    [208 rows x 1 columns],
#    'volume':               Volume
#    Date
#    2023-01-03  35221500
#    2023-01-04  41998500
#    2023-01-05  34177000
#    2023-01-06  34068700
#    2023-01-07         0
#    ...              ...
#    2023-10-26  60921000
#    2023-10-27  64709300
#    2023-10-28         0
#    2023-10-29         0
#    2023-10-30  41891900
#
#    [301 rows x 1 columns]},
#   {'ticker': 'BK',
#    'info': {'address1': '240 Greenwich Street',
#     'city': 'New York',
#     'state': 'NY',
#     'zip': '10286',
#     'country': 'United States',
#     'phone': '212 495 1784',
#     'website': 'https://www.bnymellon.com',
#     'industry': 'Asset Management',
#     'industryKey': 'asset-management',
#     'industryDisp': 'Asset Management',
#     'sector': 'Financial Services',
#     'sectorKey': 'financial-services',
#     'sectorDisp': 'Financial Services',
#     'longBusinessSummary': 'The Bank of New York Mellon Corporation provides a range of financial products and services in the United States and internationally. The company operates through Securities Services, Market and Wealth Services, Investment and Wealth Management, and other segments. The Securities Services segment offers custody, trust and depositary, accounting, exchange-traded funds, middle-office solutions, transfer agency, services for private equity and real estate funds, foreign exchange, securities lending, liquidity/lending services, and data analytics. This segment also provides trustee, paying agency, fiduciary, escrow and other financial, issuer, and support services for brokers and investors. The Market and Wealth Services segment offers clearing and custody, investment, wealth and retirement solutions, technology and enterprise data management, trading, and prime brokerage services. This segment also provides integrated cash management solutions, including payments, foreign exchange, liquidity management, receivables processing and payables management, and trade finance and processing services. The Investment and Wealth Management segment offers investment management strategies and distribution of investment products, investment management, custody, wealth and estate planning, private banking, investment, and information management services. The Other segment engages in the provision of leasing, corporate treasury, derivative and other trading, corporate and bank-owned life insurance, renewable energy investment, and business exit services. It serves central banks and sovereigns, financial institutions, asset managers, insurance companies, corporations, local authorities and high net-worth individuals, and family offices. The company was founded in 1784 and is headquartered in New York, New York.',
#     'fullTimeEmployees': 53600,
#     'companyOfficers': [{'maxAge': 1,
#       'name': 'Mr. Robin Antony Vince',
#       'age': 51,
#       'title': 'President, CEO & Director',
#       'yearBorn': 1971,
#       'fiscalYear': 2022,
#       'totalPay': 4497152,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Dermot William McDonogh',
#       'age': 58,
#       'title': 'Senior Executive VP & CFO',
#       'yearBorn': 1964,
#       'fiscalYear': 2022,
#       'totalPay': 2339041,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Bridget E. Engle',
#       'age': 58,
#       'title': 'Chief Information Officer & Global Head of Engineering',
#       'yearBorn': 1964,
#       'fiscalYear': 2022,
#       'totalPay': 2833600,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Roman  Regelman',
#       'age': 50,
#       'title': 'Senior EVP, Global Head of Securities Services & Digital',
#       'yearBorn': 1972,
#       'fiscalYear': 2022,
#       'totalPay': 2576200,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Emily Hope Portney',
#       'age': 50,
#       'title': 'Senior Executive Vice President & Global Head of Asset Servicing',
#       'yearBorn': 1972,
#       'fiscalYear': 2022,
#       'totalPay': 2576200,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Hanneke  Smits',
#       'age': 56,
#       'title': 'Senior EVP & Global Head of Investment Management',
#       'yearBorn': 1966,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Alejandro  Perez',
#       'title': 'Chief Administrative Officer',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Marius  Merz',
#       'title': 'Head of Investor Relations',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Mark  Musi',
#       'title': 'Chief Compliance & Ethics Officer',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Jane Kevin McCarthy',
#       'age': 57,
#       'title': 'General Counsel',
#       'yearBorn': 1965,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0}],
#     'auditRisk': 4,
#     'boardRisk': 2,
#     'compensationRisk': 2,
#     'shareHolderRightsRisk': 2,
#     'overallRisk': 1,
#     'governanceEpochDate': 1698796800,
#     'compensationAsOfEpochDate': 1672444800,
#     'maxAge': 86400,
#     'priceHint': 2,
#     'previousClose': 47.22,
#     'open': 47.25,
#     'dayLow': 47.04,
#     'dayHigh': 47.47,
#     'regularMarketPreviousClose': 47.22,
#     'regularMarketOpen': 47.25,
#     'regularMarketDayLow': 47.04,
#     'regularMarketDayHigh': 47.47,
#     'dividendRate': 1.68,
#     'dividendYield': 0.0356,
#     'exDividendDate': 1698278400,
#     'payoutRatio': 0.35830003,
#     'fiveYearAvgDividendYield': 2.87,
#     'beta': 1.078,
#     'trailingPE': 11.088993,
#     'forwardPE': 9.4510975,
#     'volume': 1519027,
#     'regularMarketVolume': 1519027,
#     'averageVolume': 4815122,
#     'averageVolume10days': 5483560,
#     'averageDailyVolume10Day': 5483560,
#     'bid': 47.14,
#     'ask': 47.66,
#     'bidSize': 800,
#     'askSize': 800,
#     'marketCap': 36415606784,
#     'fiftyTwoWeekLow': 39.65,
#     'fiftyTwoWeekHigh': 52.26,
#     'priceToSalesTrailing12Months': 2.1353118,
#     'fiftyDayAverage': 43.5338,
#     'twoHundredDayAverage': 44.4884,
#     'trailingAnnualDividendRate': 1.53,
#     'trailingAnnualDividendYield': 0.032401524,
#     'currency': 'USD',
#     'enterpriseValue': -53553381376,
#     'profitMargins': 0.2125,
#     'floatShares': 767588967,
#     'sharesOutstanding': 769073024,
#     'sharesShort': 7662431,
#     'sharesShortPriorMonth': 6830974,
#     'sharesShortPreviousMonthDate': 1695945600,
#     'dateShortInterest': 1698710400,
#     'sharesPercentSharesOut': 0.01,
#     'heldPercentInsiders': 0.0013600001,
#     'heldPercentInstitutions': 0.86447996,
#     'shortRatio': 1.57,
#     'shortPercentOfFloat': 0.01,
#     'impliedSharesOutstanding': 769073024,
#     'bookValue': 46.976,
#     'priceToBook': 1.0079614,
#     'lastFiscalYearEnd': 1672444800,
#     'nextFiscalYearEnd': 1703980800,
#     'mostRecentQuarter': 1696032000,
#     'earningsQuarterlyGrowth': 1.675,
#     'netIncomeToCommon': 3400999936,
#     'trailingEps': 4.27,
#     'forwardEps': 5.01,
#     'pegRatio': 0.93,
#     'lastSplitFactor': '9434:10000',
#     'lastSplitDate': 1183334400,
#     'enterpriseToRevenue': -3.14,
#     '52WeekChange': 0.033939123,
#     'SandP52WeekChange': 0.13176453,
#     'lastDividendValue': 0.42,
#     'lastDividendDate': 1698278400,
#     'exchange': 'NYQ',
#     'quoteType': 'EQUITY',
#     'symbol': 'BK',
#     'underlyingSymbol': 'BK',
#     'shortName': 'The Bank of New York Mellon Cor',
#     'longName': 'The Bank of New York Mellon Corporation',
#     'firstTradeDateEpochUtc': 105283800,
#     'timeZoneFullName': 'America/New_York',
#     'timeZoneShortName': 'EST',
#     'uuid': '3b16c9d4-c4c8-36ce-bfff-405e3b6c43ab',
#     'messageBoardId': 'finmb_135506',
#     'gmtOffSetMilliseconds': -18000000,
#     'currentPrice': 47.35,
#     'targetHighPrice': 62.0,
#     'targetLowPrice': 45.0,
#     'targetMeanPrice': 52.4,
#     'targetMedianPrice': 52.0,
#     'recommendationMean': 2.2,
#     'recommendationKey': 'buy',
#     'numberOfAnalystOpinions': 15,
#     'totalCash': 160353992704,
#     'totalCashPerShare': 208.503,
#     'totalDebt': 65381998592,
#     'totalRevenue': 17054000128,
#     'revenuePerShare': 21.445,
#     'returnOnAssets': 0.00871,
#     'returnOnEquity': 0.089549996,
#     'grossProfits': 16338000000,
#     'operatingCashflow': 10904000512,
#     'earningsGrowth': 2.128,
#     'revenueGrowth': 0.014,
#     'grossMargins': 0.0,
#     'ebitdaMargins': 0.0,
#     'operatingMargins': 0.29673,
#     'financialCurrency': 'USD',
#     'trailingPegRatio': 0.5175},
#    'close':                 Close
#    Date
#    2023-01-03  62.778172
#    2023-01-04  64.869925
#    2023-01-05  63.663155
#    2023-01-06  65.019724
#    2023-01-09  64.677054
#    ...               ...
#    2023-10-24  57.176867
#    2023-10-25  57.508595
#    2023-10-26  58.137816
#    2023-10-27  57.507683
#    2023-10-30  58.697635
#
#    [208 rows x 1 columns],
#    'volume':              Volume
#    Date
#    2023-01-03  5319300
#    2023-01-04  7777700
#    2023-01-05  4269000
#    2023-01-06  4277100
#    2023-01-07        0
#    ...             ...
#    2023-10-26  5049300
#    2023-10-27  5848600
#    2023-10-28        0
#    2023-10-29        0
#    2023-10-30  3817800
#
#    [301 rows x 1 columns]},
#   {'ticker': 'BLK',
#    'info': {'address1': '50 Hudson Yards',
#     'city': 'New York',
#     'state': 'NY',
#     'zip': '10001',
#     'country': 'United States',
#     'phone': '212 810 5300',
#     'website': 'https://www.blackrock.com',
#     'industry': 'Asset Management',
#     'industryKey': 'asset-management',
#     'industryDisp': 'Asset Management',
#     'sector': 'Financial Services',
#     'sectorKey': 'financial-services',
#     'sectorDisp': 'Financial Services',
#     'longBusinessSummary': 'BlackRock, Inc. is a publicly owned investment manager. The firm primarily provides its services to institutional, intermediary, and individual investors including corporate, public, union, and industry pension plans, insurance companies, third-party mutual funds, endowments, public institutions, governments, foundations, charities, sovereign wealth funds, corporations, official institutions, and banks. It also provides global risk management and advisory services. The firm manages separate client-focused equity, fixed income, and balanced portfolios. It also launches and manages open-end and closed-end mutual funds, offshore funds, unit trusts, and alternative investment vehicles including structured funds. The firm launches equity, fixed income, balanced, and real estate mutual funds. It also launches equity, fixed income, balanced, currency, commodity, and multi-asset exchange traded funds. The firm also launches and manages hedge funds. It invests in the public equity, fixed income, real estate, currency, commodity, and alternative markets across the globe. The firm primarily invests in growth and value stocks of small-cap, mid-cap, SMID-cap, large-cap, and multi-cap companies. It also invests in dividend-paying equity securities. The firm invests in investment grade municipal securities, government securities including securities issued or guaranteed by a government or a government agency or instrumentality, corporate bonds, and asset-backed and mortgage-backed securities. It employs fundamental and quantitative analysis with a focus on bottom-up and top-down approach to make its investments. The firm employs liquidity, asset allocation, balanced, real estate, and alternative strategies to make its investments. In real estate sector, it seeks to invest in Poland and Germany. The firm benchmarks the performance of its portfolios against various S&P, Russell, Barclays, MSCI, Citigroup, and Merrill Lynch indices. BlackRock, Inc. was founded in 1988 and is based in New York City with additional offices in Boston, Massachusetts; London, United Kingdom; Gurgaon, India; Hong Kong; Greenwich, Connecticut; Princeton, New Jersey; Edinburgh, United Kingdom; Sydney, Australia; Taipei, Taiwan; Singapore; Sao Paulo, Brazil; Philadelphia, Pennsylvania; Washington, District of Columbia; Toronto, Canada; Wilmington, Delaware; and San Francisco, California.',
#     'fullTimeEmployees': 19900,
#     'companyOfficers': [{'maxAge': 1,
#       'name': 'Mr. Laurence Douglas Fink',
#       'age': 70,
#       'title': 'Chairman & CEO',
#       'yearBorn': 1952,
#       'fiscalYear': 2022,
#       'totalPay': 9475555,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Robert Steven Kapito',
#       'age': 66,
#       'title': 'President & Director',
#       'yearBorn': 1956,
#       'fiscalYear': 2022,
#       'totalPay': 7133430,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Robert Lawrence Goldstein',
#       'age': 48,
#       'title': 'Senior MD & COO',
#       'yearBorn': 1974,
#       'fiscalYear': 2022,
#       'totalPay': 3104195,
#       'exercisedValue': 0,
#       'unexercisedValue': 7036193},
#      {'maxAge': 1,
#       'name': 'Mr. J. Richard Kushel',
#       'age': 55,
#       'title': 'Senior MD & Head of the Portfolio Management Group',
#       'yearBorn': 1967,
#       'fiscalYear': 2022,
#       'totalPay': 2604195,
#       'exercisedValue': 0,
#       'unexercisedValue': 5277096},
#      {'maxAge': 1,
#       'name': 'Mr. Gary Stephen Shedlin',
#       'age': 59,
#       'title': 'Vice Chairman',
#       'yearBorn': 1963,
#       'fiscalYear': 2022,
#       'totalPay': 2214794,
#       'exercisedValue': 0,
#       'unexercisedValue': 5277096},
#      {'maxAge': 1,
#       'name': 'Dr. Bennett W. Golub Ph.D.',
#       'age': 64,
#       'title': 'Co-Founder',
#       'yearBorn': 1958,
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Mark  McKenna',
#       'title': 'Founder, MD, Global Head of Event Driven Equity Strategies & Portfolio Manager',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Martin  Small',
#       'title': 'Senior MD, CFO & Global Head of Corporate Strategy',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Dr. Jeff  Shen Ph.D.',
#       'title': 'MD, Co-CIO & Co-Head of Systematic Active Equity (SAE)',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Neeraj  Seth',
#       'title': 'MD, Chief Investment Officer & Head of Asian credit \x96 Singapore',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0}],
#     'auditRisk': 6,
#     'boardRisk': 7,
#     'compensationRisk': 6,
#     'shareHolderRightsRisk': 1,
#     'overallRisk': 4,
#     'governanceEpochDate': 1698796800,
#     'compensationAsOfEpochDate': 1672444800,
#     'maxAge': 86400,
#     'priceHint': 2,
#     'previousClose': 727.14,
#     'open': 726.72,
#     'dayLow': 726.64,
#     'dayHigh': 730.74,
#     'regularMarketPreviousClose': 727.14,
#     'regularMarketOpen': 726.72,
#     'regularMarketDayLow': 726.64,
#     'regularMarketDayHigh': 730.74,
#     'dividendRate': 20.0,
#     'dividendYield': 0.0275,
#     'exDividendDate': 1701820800,
#     'payoutRatio': 0.8532,
#     'fiveYearAvgDividendYield': 2.54,
#     'beta': 1.294,
#     'trailingPE': 31.37516,
#     'forwardPE': 19.464144,
#     'volume': 273501,
#     'regularMarketVolume': 273501,
#     'averageVolume': 625971,
#     'averageVolume10days': 615840,
#     'averageDailyVolume10Day': 615840,
#     'bid': 729.1,
#     'ask': 730.89,
#     'bidSize': 1000,
#     'askSize': 800,
#     'marketCap': 108611133440,
#     'fiftyTwoWeekLow': 596.18,
#     'fiftyTwoWeekHigh': 781.77,
#     'priceToSalesTrailing12Months': 6.183384,
#     'fiftyDayAverage': 653.5164,
#     'twoHundredDayAverage': 675.8768,
#     'trailingAnnualDividendRate': 19.88,
#     'trailingAnnualDividendYield': 0.027339987,
#     'currency': 'USD',
#     'enterpriseValue': 113209483264,
#     'profitMargins': 0.30663002,
#     'floatShares': 139287789,
#     'sharesOutstanding': 148762000,
#     'sharesShort': 1510318,
#     'sharesShortPriorMonth': 2205398,
#     'sharesShortPreviousMonthDate': 1695945600,
#     'dateShortInterest': 1698710400,
#     'sharesPercentSharesOut': 0.010199999,
#     'heldPercentInsiders': 0.01028,
#     'heldPercentInstitutions': 0.84982,
#     'shortRatio': 2.29,
#     'shortPercentOfFloat': 0.010299999,
#     'impliedSharesOutstanding': 148762000,
#     'bookValue': 259.341,
#     'priceToBook': 2.8152122,
#     'lastFiscalYearEnd': 1672444800,
#     'nextFiscalYearEnd': 1703980800,
#     'mostRecentQuarter': 1696032000,
#     'earningsQuarterlyGrowth': 0.141,
#     'netIncomeToCommon': 5385999872,
#     'trailingEps': 23.27,
#     'forwardEps': 37.51,
#     'pegRatio': 2.43,
#     'enterpriseToRevenue': 6.445,
#     'enterpriseToEbitda': 17.06,
#     '52WeekChange': -0.014421642,
#     'SandP52WeekChange': 0.13176453,
#     'lastDividendValue': 5.0,
#     'lastDividendDate': 1694044800,
#     'exchange': 'NYQ',
#     'quoteType': 'EQUITY',
#     'symbol': 'BLK',
#     'underlyingSymbol': 'BLK',
#     'shortName': 'BlackRock, Inc.',
#     'longName': 'BlackRock, Inc.',
#     'firstTradeDateEpochUtc': 938784600,
#     'timeZoneFullName': 'America/New_York',
#     'timeZoneShortName': 'EST',
#     'uuid': '386ad08c-9fb4-35ee-a9b0-7905b98af57b',
#     'messageBoardId': 'finmb_403413',
#     'gmtOffSetMilliseconds': -18000000,
#     'currentPrice': 730.1,
#     'targetHighPrice': 897.0,
#     'targetLowPrice': 675.0,
#     'targetMeanPrice': 761.69,
#     'targetMedianPrice': 740.0,
#     'recommendationMean': 1.9,
#     'recommendationKey': 'buy',
#     'numberOfAnalystOpinions': 13,
#     'totalCash': 7070000128,
#     'totalCashPerShare': 47.525,
#     'ebitda': 6636000256,
#     'totalDebt': 9664000000,
#     'quickRatio': 1.408,
#     'currentRatio': 2.051,
#     'totalRevenue': 17564999680,
#     'debtToEquity': 23.785,
#     'revenuePerShare': 117.357,
#     'returnOnAssets': 0.03317,
#     'returnOnEquity': 0.13953,
#     'grossProfits': 8787000000,
#     'freeCashflow': 3652250112,
#     'operatingCashflow': 4140000000,
#     'earningsGrowth': 0.152,
#     'revenueGrowth': 0.049,
#     'grossMargins': 0.48534,
#     'ebitdaMargins': 0.3778,
#     'operatingMargins': 0.36201,
#     'financialCurrency': 'USD',
#     'trailingPegRatio': 4.1948},
#    'close':                   Close
#    Date
#    2023-01-03   965.455059
#    2023-01-04   987.133263
#    2023-01-05   945.629133
#    2023-01-06  1000.720654
#    2023-01-09  1011.657148
#    ...                 ...
#    2023-10-24   838.270093
#    2023-10-25   836.423717
#    2023-10-26   837.932703
#    2023-10-27   826.187722
#    2023-10-30   841.674717
#
#    [208 rows x 1 columns],
#    'volume':              Volume
#    Date
#    2023-01-03   540800
#    2023-01-04   710200
#    2023-01-05   686700
#    2023-01-06  1215700
#    2023-01-07        0
#    ...             ...
#    2023-10-26   856400
#    2023-10-27   543000
#    2023-10-28        0
#    2023-10-29        0
#    2023-10-30   528100
#
#    [301 rows x 1 columns]},
#   {'ticker': 'C',
#    'info': {'address1': '388 Greenwich Street',
#     'city': 'New York',
#     'state': 'NY',
#     'zip': '10013',
#     'country': 'United States',
#     'phone': '212 559 1000',
#     'website': 'https://www.citigroup.com',
#     'industry': 'Banks - Diversified',
#     'industryKey': 'banks-diversified',
#     'industryDisp': 'Banks - Diversified',
#     'sector': 'Financial Services',
#     'sectorKey': 'financial-services',
#     'sectorDisp': 'Financial Services',
#     'longBusinessSummary': 'Citigroup Inc., a diversified financial services holding company, provides various financial products and services to consumers, corporations, governments, and institutions in North America, Latin America, Asia, Europe, the Middle East, and Africa. It operates through three segments: Institutional Clients Group (ICG), Personal Banking and Wealth Management (PBWM), and Legacy Franchises. The ICG segment offers wholesale banking products and services, including fixed income and equity sales and trading, foreign exchange, prime brokerage, derivative, equity and fixed income research, corporate lending, investment banking and advisory, private banking, cash management, trade finance, and securities services to corporate, institutional, and public sector clients. The PBWM segment offers traditional banking services to retail and small business customers through retail banking, cash, rewards, value portfolios, and co-branded cards. It also provides various banking, credit cards, custody, trust, mortgages, home equity, small business, and personal consumer loans. The Legacy Franchises segment provides traditional retail banking and branded card products to retail and small business customers. The company was founded in 1812 and is headquartered in New York, New York.',
#     'fullTimeEmployees': 240000,
#     'companyOfficers': [{'maxAge': 1,
#       'name': 'Ms. Jane Nind Fraser',
#       'age': 54,
#       'title': 'CEO & Director',
#       'yearBorn': 1968,
#       'fiscalYear': 2022,
#       'totalPay': 6530800,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Mark A.L. Mason',
#       'age': 52,
#       'title': 'Chief Financial Officer',
#       'yearBorn': 1970,
#       'fiscalYear': 2022,
#       'totalPay': 7842539,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Anand  Selvakesari',
#       'age': 54,
#       'title': 'Chief Operating Officer',
#       'yearBorn': 1968,
#       'fiscalYear': 2022,
#       'totalPay': 8453987,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Paco  Ybarra',
#       'age': 60,
#       'title': 'Senior Advisor',
#       'yearBorn': 1962,
#       'fiscalYear': 2022,
#       'totalPay': 12318942,
#       'exercisedValue': 0,
# ...
#     'fullTimeEmployees': 1500000,
#     'companyOfficers': [{'maxAge': 1,
#       'name': 'Mr. Jeffrey P. Bezos',
#       'age': 58,
#       'title': 'Founder & Executive Chairman',
#       'yearBorn': 1964,
#       'fiscalYear': 2022,
#       'totalPay': 1681840,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Andrew R. Jassy',
#       'age': 54,
#       'title': 'President, CEO & Director',
#       'yearBorn': 1968,
#       'fiscalYear': 2022,
#       'totalPay': 1298723,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Brian T. Olsavsky',
#       'age': 58,
#       'title': 'Senior VP & CFO',
#       'yearBorn': 1964,
#       'fiscalYear': 2022,
#       'totalPay': 319850,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. David A. Zapolsky',
#       'age': 58,
#       'title': 'Senior VP of Global Public Policy & General Counsel',
#       'yearBorn': 1964,
#       'fiscalYear': 2022,
#       'totalPay': 319850,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Douglas J. Herrington',
#       'age': 55,
#       'title': 'Chief Executive Officer of Worldwide Amazon Stores',
#       'yearBorn': 1967,
#       'fiscalYear': 2022,
#       'totalPay': 335438,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Adam N. Selipsky',
#       'age': 55,
#       'title': 'Chief Executive Officer of Amazon Web Services, Inc.',
#       'yearBorn': 1967,
#       'fiscalYear': 2022,
#       'totalPay': 360613,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Shelley L. Reynolds',
#       'age': 57,
#       'title': 'VP, Worldwide Controller & Principal Accounting Officer',
#       'yearBorn': 1965,
#       'fiscalYear': 2022,
#       'totalPay': 163200,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Dr. Werner  Vogels',
#       'title': 'Chief Technology Officer',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Dave  Fildes',
#       'title': 'Director of Investor Relations',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Anuradha  Aggarwal',
#       'title': 'CMO & Director of User Growth',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0}],
#     'auditRisk': 5,
#     'boardRisk': 10,
#     'compensationRisk': 10,
#     'shareHolderRightsRisk': 2,
#     'overallRisk': 10,
#     'governanceEpochDate': 1698796800,
#     'compensationAsOfEpochDate': 1672444800,
#     'maxAge': 86400,
#     'priceHint': 2,
#     'previousClose': 146.71,
#     'open': 146.7,
#     'dayLow': 145.33,
#     'dayHigh': 147.2,
#     'regularMarketPreviousClose': 146.71,
#     'regularMarketOpen': 146.7,
#     'regularMarketDayLow': 145.33,
#     'regularMarketDayHigh': 147.2,
#     'payoutRatio': 0.0,
#     'beta': 1.175,
#     'trailingPE': 76.82723,
#     'forwardPE': 41.45198,
#     'volume': 22378379,
#     'regularMarketVolume': 22378379,
#     'averageVolume': 53291530,
#     'averageVolume10days': 49989060,
#     'averageDailyVolume10Day': 49989060,
#     'bid': 146.63,
#     'ask': 146.7,
#     'bidSize': 800,
#     'askSize': 800,
#     'marketCap': 1516411289600,
#     'fiftyTwoWeekLow': 81.43,
#     'fiftyTwoWeekHigh': 147.74,
#     'priceToSalesTrailing12Months': 2.7370663,
#     'fiftyDayAverage': 133.8724,
#     'twoHundredDayAverage': 121.013,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'currency': 'USD',
#     'enterpriseValue': 1618311643136,
#     'profitMargins': 0.03624,
#     'floatShares': 9061394719,
#     'sharesOutstanding': 10334000128,
#     'sharesShort': 75158089,
#     'sharesShortPriorMonth': 76818818,
#     'sharesShortPreviousMonthDate': 1695945600,
#     'dateShortInterest': 1698710400,
#     'sharesPercentSharesOut': 0.0073,
#     'heldPercentInsiders': 0.09718,
#     'heldPercentInstitutions': 0.60534,
#     'shortRatio': 1.35,
#     'shortPercentOfFloat': 0.0095999995,
#     'impliedSharesOutstanding': 10334000128,
#     'bookValue': 17.713,
#     'priceToBook': 8.284311,
#     'lastFiscalYearEnd': 1672444800,
#     'nextFiscalYearEnd': 1703980800,
#     'mostRecentQuarter': 1696032000,
#     'earningsQuarterlyGrowth': 2.44,
#     'netIncomeToCommon': 20078999552,
#     'trailingEps': 1.91,
#     'forwardEps': 3.54,
#     'pegRatio': 0.63,
#     'lastSplitFactor': '20:1',
#     'lastSplitDate': 1654473600,
#     'enterpriseToRevenue': 2.921,
#     'enterpriseToEbitda': 21.876,
#     '52WeekChange': 0.5706028,
#     'SandP52WeekChange': 0.13176453,
#     'exchange': 'NMS',
#     'quoteType': 'EQUITY',
#     'symbol': 'AMZN',
#     'underlyingSymbol': 'AMZN',
#     'shortName': 'Amazon.com, Inc.',
#     'longName': 'Amazon.com, Inc.',
#     'firstTradeDateEpochUtc': 863703000,
#     'timeZoneFullName': 'America/New_York',
#     'timeZoneShortName': 'EST',
#     'uuid': '261fd26b-0151-3813-b0d0-97e4ed4c6505',
#     'messageBoardId': 'finmb_18749',
#     'gmtOffSetMilliseconds': -18000000,
#     'currentPrice': 146.74,
#     'targetHighPrice': 230.0,
#     'targetLowPrice': 128.0,
#     'targetMeanPrice': 172.94,
#     'targetMedianPrice': 175.0,
#     'recommendationMean': 1.7,
#     'recommendationKey': 'buy',
#     'numberOfAnalystOpinions': 48,
#     'totalCash': 64169000960,
#     'totalCashPerShare': 6.209,
#     'ebitda': 73978003456,
#     'totalDebt': 166064996352,
#     'quickRatio': 0.701,
#     'currentRatio': 0.985,
#     'totalRevenue': 554027974656,
#     'debtToEquity': 90.759,
#     'revenuePerShare': 53.946,
#     'returnOnAssets': 0.03612,
#     'returnOnEquity': 0.12531,
#     'grossProfits': 225152000000,
#     'freeCashflow': 36392374272,
#     'operatingCashflow': 71653998592,
#     'earningsGrowth': 2.357,
#     'revenueGrowth': 0.126,
#     'grossMargins': 0.46243998,
#     'ebitdaMargins': 0.13352999,
#     'operatingMargins': 0.07819,
#     'financialCurrency': 'USD',
#     'trailingPegRatio': 2.6198},
#    'close':                  Close
#    Date
#    2023-01-03  116.363344
#    2023-01-04  116.421281
#    2023-01-05  112.088154
#    2023-01-06  116.723626
#    2023-01-09  117.369912
#    ...                ...
#    2023-10-24  175.979357
#    2023-10-25  166.809285
#    2023-10-26  165.041283
#    2023-10-27  176.460030
#    2023-10-30  183.981187
#
#    [208 rows x 1 columns],
#    'volume':                Volume
#    Date
#    2023-01-03   76706000
#    2023-01-04   68885100
#    2023-01-05   67930800
#    2023-01-06   83303400
#    2023-01-07          0
#    ...               ...
#    2023-10-26  100419500
#    2023-10-27  125309300
#    2023-10-28          0
#    2023-10-29          0
#    2023-10-30   72485500
#
#    [301 rows x 1 columns]}],
#  'Communication Services': [{'ticker': 'T.TO',
#    'info': {'address1': '510 West Georgia Street',
#     'address2': 'Floor 23',
#     'city': 'Vancouver',
#     'state': 'BC',
#     'zip': 'V6B 0M3',
#     'country': 'Canada',
#     'website': 'https://www.telus.com',
#     'industry': 'Telecom Services',
#     'industryKey': 'telecom-services',
#     'industryDisp': 'Telecom Services',
#     'sector': 'Communication Services',
#     'sectorKey': 'communication-services',
#     'sectorDisp': 'Communication Services',
#     'longBusinessSummary': 'TELUS Corporation, together with its subsidiaries, provides a range of telecommunications and information technology products and services in Canada. It operates through Technology Solutions and Digitally-Led Customer Experiences segments. The Technology Solutions segment offers a range of telecommunications products and services; network services; mobile technologies equipment; data services, such as internet protocol; television; hosting, managed information technology, and cloud-based services; software, data management, and data analytics-driven smart food-chain and consumer goods technologies; home and business security; healthcare software and technology solutions; and voice and other telecommunications services. The Digitally-Led Customer Experiences segment provides digital customer experience and digital-enablement transformation solutions, including artificial intelligence and content management solutions. The company was formerly known as TELUS Communications Inc. and changed its name to TELUS Corporation in February 2005. TELUS Corporation was incorporated in 1998 and is based in Vancouver, Canada.',
#     'fullTimeEmployees': 108500,
#     'companyOfficers': [{'maxAge': 1,
#       'name': 'Mr. Darren  Entwistle B.A., LL.D., M.B.A.',
#       'age': 58,
#       'title': 'President, CEO & Director',
#       'yearBorn': 1964,
#       'fiscalYear': 2022,
#       'totalPay': 2829445,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Douglas  French',
#       'age': 56,
#       'title': 'Executive VP & CFO',
#       'yearBorn': 1966,
#       'fiscalYear': 2022,
#       'totalPay': 1379309,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Tony  Geheran',
#       'age': 59,
#       'title': 'COO & EVP',
#       'yearBorn': 1963,
#       'fiscalYear': 2022,
#       'totalPay': 1391305,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Navin  Arora',
#       'age': 50,
#       'title': 'Executive VP & President of Business Solutions',
#       'yearBorn': 1972,
#       'fiscalYear': 2022,
#       'totalPay': 1011442,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Zainul  Mawji',
#       'title': 'EVP & President of Telus Consumer Solutions',
#       'fiscalYear': 2022,
#       'totalPay': 954275,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Robert  Mitchell',
#       'title': 'Head of Investor Relations',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Andrea Louise Wood LLB LLM',
#       'title': 'Chief Legal & Governance Officer',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Jill  Schnarr',
#       'title': 'Chief Communications & Brand Officer',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Ms. Sandy  McIntosh',
#       'title': 'Executive VP of People & Culture and Chief Human Resources Officer',
#       'fiscalYear': 2022,
#       'exercisedValue': 0,
#       'unexercisedValue': 0},
#      {'maxAge': 1,
#       'name': 'Mr. Francois  Cote',
#       'age': 64,
#       'title': 'Executive Vice President',
#       'yearBorn': 1958,
#       'fiscalYear': 2022,
#       'totalPay': 564933,
#       'exercisedValue': 0,
#       'unexercisedValue': 0}],
#     'auditRisk': 3,
#     'boardRisk': 2,
#     'compensationRisk': 3,
#     'shareHolderRightsRisk': 3,
#     'overallRisk': 2,
#     'governanceEpochDate': 1698796800,
#     'compensationAsOfEpochDate': 1672444800,
#     'maxAge': 86400,
#     'priceHint': 2,
#     'previousClose': 24.04,
#     'open': 24.01,
#     'dayLow': 23.965,
#     'dayHigh': 24.14,
#     'regularMarketPreviousClose': 24.04,
#     'regularMarketOpen': 24.01,
#     'regularMarketDayLow': 23.965,
#     'regularMarketDayHigh': 24.14,
#     'dividendRate': 1.5,
#     'dividendYield': 0.0626,
#     'exDividendDate': 1701993600,
#     'payoutRatio': 2.647,
#     'fiveYearAvgDividendYield': 4.72,
#     'beta': 0.682,
#     'trailingPE': 44.555553,
#     'forwardPE': 21.872726,
#     'volume': 1352743,
#     'regularMarketVolume': 1352743,
#     'averageVolume': 2447555,
#     'averageVolume10days': 1709450,
#     'averageDailyVolume10Day': 1709450,
#     'bid': 24.07,
#     'ask': 24.08,
#     'bidSize': 0,
#     'askSize': 0,
#     'marketCap': 35007299584,
#     'fiftyTwoWeekLow': 21.16,
#     'fiftyTwoWeekHigh': 29.15,
#     'priceToSalesTrailing12Months': 1.7616395,
#     'fiftyDayAverage': 23.013,
#     'twoHundredDayAverage': 25.2478,
#     'trailingAnnualDividendRate': 1.429,
#     'trailingAnnualDividendYield': 0.059442595,
#     'currency': 'CAD',
#     'enterpriseValue': 62952300544,
#     'profitMargins': 0.040310003,
#     'floatShares': 1453443150,
#     'sharesOutstanding': 1455000064,
#     'sharesShort': 56587894,
#     'sharesShortPriorMonth': 57325958,
#     'sharesShortPreviousMonthDate': 1697155200,
#     'dateShortInterest': 1700006400,
#     'sharesPercentSharesOut': 0.038900003,
#     'heldPercentInsiders': 0.00017000001,
#     'heldPercentInstitutions': 0.56726,
#     'shortRatio': 27.96,
#     'impliedSharesOutstanding': 1463480064,
#     'bookValue': 11.214,
#     'priceToBook': 2.1455324,
#     'lastFiscalYearEnd': 1672444800,
#     'nextFiscalYearEnd': 1703980800,
#     'mostRecentQuarter': 1696032000,
#     'earningsQuarterlyGrowth': -0.735,
#     'netIncomeToCommon': 801000000,
#     'trailingEps': 0.54,
#     'forwardEps': 1.1,
#     'pegRatio': 4.3,
#     'lastSplitFactor': '2:1',
#     'lastSplitDate': 1584489600,
#     'enterpriseToRevenue': 3.168,
#     'enterpriseToEbitda': 13.309,
#     '52WeekChange': -0.1721763,
#     'SandP52WeekChange': 0.13176453,
#     'lastDividendValue': 0.364,
#     'lastDividendDate': 1694044800,
#     'exchange': 'TOR',
#     'quoteType': 'EQUITY',
#     'symbol': 'T.TO',
#     'underlyingSymbol': 'T.TO',
#     'shortName': 'TELUS CORPORATION',
#     'longName': 'TELUS Corporation',
#     'firstTradeDateEpochUtc': 789921000,
#     'timeZoneFullName': 'America/Toronto',
#     'timeZoneShortName': 'EST',
#     'uuid': '581aa5df-00aa-3335-b7f9-a711f61bc185',
#     'messageBoardId': 'finmb_598689',
#     'gmtOffSetMilliseconds': -18000000,
#     'currentPrice': 24.06,
#     'targetHighPrice': 30.0,
#     'targetLowPrice': 24.0,
#     'targetMeanPrice': 26.76,
#     'targetMedianPrice': 26.9,
#     'recommendationMean': 2.1,
#     'recommendationKey': 'buy',
#     'numberOfAnalystOpinions': 17,
#     'totalCash': 1208000000,
#     'totalCashPerShare': 0.83,
#     'ebitda': 4729999872,
#     'totalDebt': 27964000256,
#     'quickRatio': 0.524,
#     'currentRatio': 0.665,
#     'totalRevenue': 19872000000,
#     'debtToEquity': 159.74,
#     'revenuePerShare': 13.776,
#     'returnOnAssets': 0.0337,
#     'returnOnEquity': 0.04654,
#     'grossProfits': 6518000000,
#     'freeCashflow': 1493250048,
#     'operatingCashflow': 4311000064,
#     'earningsGrowth': -0.755,
#     'revenueGrowth': 0.075,
#     'grossMargins': 0.34642,
#     'ebitdaMargins': 0.23802,
#     'operatingMargins': 0.16112,
#     'financialCurrency': 'CAD',
#     'trailingPegRatio': None},
#    'close':                 Close
#    Date
#    2023-01-03  26.320000
#    2023-01-04  26.639999
#    2023-01-05  26.610001
#    2023-01-06  27.020000
#    2023-01-09  26.959999
#    ...               ...
#    2023-10-24  22.360001
#    2023-10-25  22.280001
#    2023-10-26  22.320000
#    2023-10-27  22.010000
#    2023-10-30  22.360001
#
#    [208 rows x 1 columns],
#    'volume':              Volume
#    Date
#    2023-01-03  2380200
#    2023-01-04  1555900
#    2023-01-05  1528600
#    2023-01-06  2051700
#    2023-01-07        0
#    ...             ...
#    2023-10-26  1127500
#    2023-10-27  2097900
#    2023-10-28        0
#    2023-10-29        0
#    2023-10-30  1875200
#
#    [301 rows x 1 columns]}]}

# %% [markdown]
# For each sector, we calculate its beta with the "market"

# %%
# calculates the beta of a list of tickers (relative to a market index)
# assumes that the stocks are all denominated in the same currency as the market index
# For our purposes, we will use daily data, since we want to assess how stocks perform relative to the market in
# the short term (we are only investing for 5 days).
# market data and stock data should have the same period and interval for consistency
def calculate_beta(market_data, stock_dict):
    # calculate market index returns
    returns = market_data
    returns = returns.rename(columns={'Close': 'Market'})
    returns = returns.pct_change()
    returns.drop(index=returns.index[0], inplace=True)
    betas = []
    
    # calculate returns for the stock and adds it to the overall dataframe
    stockReturns = stock_dict['close']
    stockReturns = stockReturns.rename(columns={'Close': stock_dict['ticker']})
    stockReturns = stockReturns.pct_change()
    stockReturns.drop(index=stockReturns.index[0], inplace=True)
    returns = returns.merge(stockReturns,left_index=True,right_index=True)
    
    # calculates covariance and market variance
    returnsCov = returns.cov()
    var = returns['Market'].var()
    beta = returnsCov/var
    
    return beta.iat[1,0]

# %%
# aggregate score for each industry is initially zero
industry_scores = {}
for sector in stocks_in_industry_list:
    industry_scores[sector] = 0

# %%
# get market data (we are using s&p 500)
market_data = yf.Ticker('^GSPC').history(start=startdate, end=enddate)[['Close']]#,period='1y',interval='1d'
market_data.index = market_data.index.strftime('%Y-%m-%d')

# consider beta for each industry (relative to s&p 500)
for sector in stocks_in_industry_list:
    stock_lst = stocks_in_industry_list[sector]
    beta_avg = 0
    for stock in stock_lst:
        ourbeta = calculate_beta(market_data,stock)
        beta_avg += ourbeta
    beta_avg /= len(stock_lst)
    industry_scores[sector] += beta_avg*0.3
print(industry_scores)
# Out:
# {'Financial Services': 0.3097982817831833, 'Healthcare': 0.10364006639539348, 'Consumer Defensive': 0.10043489741338855, 'Technology': 0.39960448181256747, 'Industrials': 0.24659159472199643, 'Consumer Cyclical': 0.46417170218430726, 'Communication Services': 0.11725599976322461}

# %%
# consider standard deviations for each industry
for sector in stocks_in_industry_list:
    stock_lst = stocks_in_industry_list[sector]
    std_avg = 0
    for stock in stock_lst:
        close_pct = stock['close'].pct_change()
        close_pct.drop(index=close_pct.index[0], inplace=True)
        std_avg += close_pct['Close'].std()
    std_avg /= len(stock_lst)
    industry_scores[sector] += std_avg*20
print(industry_scores)
# Out:
# {'Financial Services': 0.6416282269993216, 'Healthcare': 0.3814143955100109, 'Consumer Defensive': 0.31290079587900316, 'Technology': 0.7983445365110385, 'Industrials': 0.564918083947961, 'Consumer Cyclical': 0.9028671143852839, 'Communication Services': 0.32757425876332313}

# %%
# consider 52 week range (high divided by low) for each industry
for sector in stocks_in_industry_list:
    stock_lst = stocks_in_industry_list[sector]
    hilo_avg = 0
    for stock in stock_lst:
        hilo_avg += stock['info']['fiftyTwoWeekHigh']/stock['info']['fiftyTwoWeekLow']
    hilo_avg /= len(stock_lst)
    industry_scores[sector] += hilo_avg*0.1
print(industry_scores)
# Out:
# {'Financial Services': 0.7856951923987333, 'Healthcare': 0.5325265866863294, 'Consumer Defensive': 0.435340023750353, 'Technology': 0.9570715569757586, 'Industrials': 0.7036242767754374, 'Consumer Cyclical': 1.08429901908871, 'Communication Services': 0.4653341831489564}

# %%
# Adjust industry score by number of stocks within
for sector in stocks_in_industry_list:
    stock_lst = stocks_in_industry_list[sector]
    industry_scores[sector] *= 1-2**(-len(stock_lst))
print(industry_scores)
# Out:
# {'Financial Services': 0.7849279119374064, 'Healthcare': 0.5304464047070859, 'Consumer Defensive': 0.42853783587925376, 'Technology': 0.9271630708202662, 'Industrials': 0.681636018126205, 'Consumer Cyclical': 0.542149509544355, 'Communication Services': 0.2326670915744782}

# %%
# Format and print final result

# convert industry_scores to a list so we can sort it
industry_scores_temp = []
for sector in industry_scores:
    industry_scores_temp.append((sector,industry_scores[sector]))
industry_scores = industry_scores_temp

from functools import cmp_to_key
# comparison function that sorts tuples by their second value in descending order
def sort_by_second_desc(a, b):
    if a[1] < b[1]:
        return 1
    elif a[1] > b[1]:
        return -1
    else:
        return 0
    
#sort industries by aggregate score in descending order
industry_scores.sort(key=cmp_to_key(sort_by_second_desc))
print(industry_scores)
# Out:
# [('Technology', 0.9271630708202662), ('Financial Services', 0.7849279119374064), ('Industrials', 0.681636018126205), ('Consumer Cyclical', 0.542149509544355), ('Healthcare', 0.5304464047070859), ('Consumer Defensive', 0.42853783587925376), ('Communication Services', 0.2326670915744782)]

# %%
# Plan: consider the most volatile industries first and assign each stock in those industries the highest weighting allowed
N_stocks = 10
principal = 750000

#stock_weightings[i] is the weight of the ith stock considered
stock_weightings = [0.2,0.2,0.2,0.1,0.05,0.05,0.05,0.05,0.05,0.05]
# a list of tuples, each tuple stores a ticker string and its corresponding portfolio weighting
stock_percentages = []
for industry in industry_scores:
    
    if len(stock_percentages) >= N_stocks:
        break

    industry_name = industry[0]
    print(industry_name)
    industry_score = industry[1]
    stock_lst = stocks_in_industry_list[industry_name]
    
    # as a tie breaker, we first consider the stocks within the current industry with the highest std
    stock_stds = []
    for stock in stock_lst:
        stock_returns = stock['close'].pct_change()
        stock_returns.drop(index=stock_returns.index[0], inplace=True)
        stock_stds.append((stock['ticker'],stock_returns['Close'].std()))
    stock_stds.sort(key=cmp_to_key(sort_by_second_desc))
    print(stock_stds)
    for stock in stock_stds:
        if len(stock_percentages) >= N_stocks:
            break
        stock_percentages.append((stock[0],stock_weightings[len(stock_percentages)]))

print(stock_percentages)

Portfolio_Final = {'Ticker': [],
                   'Price': [],
                   'Currency': [],
                   'Shares': [],
                   'Value': [],
                   'Weight': []
                  }

curr_cad_usd = yf.Ticker('CADUSD=x').info['previousClose']
for stock in stock_percentages:
    stock_info = yf.Ticker(stock[0]).info
    curr_price = stock_info['currentPrice']
    Portfolio_Final['Ticker'].append(stock[0])
    Portfolio_Final['Price'].append(curr_price)
    Portfolio_Final['Currency'].append(stock_info['currency'])
    num_shares = 0
    if stock_info['currency'] == 'USD':
        num_shares = principal*stock[1]/(curr_price/curr_cad_usd)
    else:
        num_shares = principal*stock[1]/curr_price
    Portfolio_Final['Shares'].append(num_shares)
    Portfolio_Final['Value'].append(principal*stock[1])
    Portfolio_Final['Weight'].append(stock[1])
    
Portfolio_Final = pd.DataFrame(data=Portfolio_Final,index=[(i+1) for i in range(N_stocks)])
Portfolio_Final
# Out:
# Technology
# [('SHOP.TO', 0.03525100825025024), ('QCOM', 0.020696286868656356), ('TXN', 0.015591193442479334), ('ACN', 0.014876924598013269), ('AAPL', 0.013269600515218569)]
# Financial Services
# [('USB', 0.02556325465929087), ('PYPL', 0.02270225473418308), ('AIG', 0.017686861508759193), ('AXP', 0.017153095145726868), ('BAC', 0.016648149352155615), ('BK', 0.016242535803549337), ('C', 0.016224530521288704), ('BLK', 0.013482523539544603), ('TD.TO', 0.010949856846754842), ('RY.TO', 0.00926191049681605)]
# [('SHOP.TO', 0.2), ('QCOM', 0.2), ('TXN', 0.2), ('ACN', 0.1), ('AAPL', 0.05), ('USB', 0.05), ('PYPL', 0.05), ('AIG', 0.05), ('AXP', 0.05), ('BAC', 0.05)]
#      Ticker   Price Currency       Shares     Value  Weight
# 1   SHOP.TO   96.26      CAD  1558.279659  150000.0    0.20
# 2      QCOM  127.75      USD   857.476497  150000.0    0.20
# 3       TXN  153.59      USD   713.214548  150000.0    0.20
# 4       ACN  334.04      USD   163.966325   75000.0    0.10
# 5      AAPL  189.97      USD   144.157791   37500.0    0.05
# 6       USB   37.20      USD   736.173538   37500.0    0.05
# 7      PYPL   55.76      USD   491.134427   37500.0    0.05
# 8       AIG   65.21      USD   419.960982   37500.0    0.05
# 9       AXP  164.42      USD   166.559151   37500.0    0.05
# 10      BAC   29.73      USD   921.145497   37500.0    0.05

# %%
#(TSX:SHOP)*1558.279659+(NASDAQ:QCOM)*857.476497*(FX_IDC:CADUSD)+(NASDAQ:TXN)*713.214548*(FX_IDC:CADUSD)+(NYSE:ACN)*163.966325*(FX_IDC:CADUSD)+(NASDAQ:AAPL)*144.157791*(FX_IDC:CADUSD)+(NYSE:USB)*736.173538*(FX_IDC:CADUSD)+(NASDAQ:PYPL)*491.134427+(NYSE:AIG)*419.960982*(FX_IDC:CADUSD)+(NYSE:AXP)*166.559151+(NYSE:BAC)*921.145497*(FX_IDC:CADUSD)

# %%
TSX:SHOP*1558.279659*(FX:USDCAD)+NASDAQ:QCOM*857.476497+NASDAQ:TXN*713.214548+NYSE:ACN*163.966325+NASDAQ:AAPL*144.157791+NYSE:USB*736.173538+NASDAQ:PYPL*491.134427+NYSE:AIG*419.960982+NYSE:AXP*166.559151+NYSE:BAC*921.145497
